# %%
import json

def is_valid_data(data):
    if "entities" not in data or "relations" not in data:
        return False
    for entity in data["entities"]:
        if "id" not in entity or "label" not in entity or "start_offset" not in entity or "end_offset" not in entity:
            return False
    for relation in data["relations"]:
        if "id" not in relation or "from_id" not in relation or "to_id" not in relation or "type" not in relation:
            return False
    return True

def process_line(line):
    line = line.replace("```json", "").replace("```", "").strip()
    return line

def extract_data(input_path, output_path, error_log_path):
    valid_data_count = 0
    line_count = 0
    buffer = ""
    inside_object = False
    inside_array = False
    errors = []

    with open(input_path, 'r', encoding='utf-8') as infile, open(output_path, 'w', encoding='utf-8') as outfile, open(error_log_path, 'w', encoding='utf-8') as error_log:
        for line in infile:
            line_count += 1
            line = process_line(line)

            if not line:
                continue  # 跳过空行

            if line.startswith("[") and not inside_array:
                inside_array = True
                buffer = line
            elif line.startswith("]") and inside_array:
                inside_array = False
                buffer += line
                try:
                    data = json.loads(buffer)
                    if isinstance(data, list):
                        for item in data:
                            if is_valid_data(item):
                                outfile.write(json.dumps(item, ensure_ascii=False) + '\n')
                                valid_data_count += 1
                except json.JSONDecodeError as e:
                    errors.append(buffer)
                    error_log.write(f"Line {line_count}: {buffer}\n")
                buffer = ""
            elif inside_array:
                buffer += line
            elif line.startswith("{") and not inside_object:
                inside_object = True
                buffer = line
            elif line.startswith("}") and inside_object:
                inside_object = False
                buffer += line
                try:
                    data = json.loads(buffer)
                    if is_valid_data(data):
                        outfile.write(json.dumps(data, ensure_ascii=False) + '\n')
                        valid_data_count += 1
                except json.JSONDecodeError as e:
                    errors.append(buffer)
                    error_log.write(f"Line {line_count}: {buffer}\n")
                buffer = ""
            elif inside_object:
                buffer += line
            else:
                try:
                    data = json.loads(line)
                    if is_valid_data(data):
                        outfile.write(json.dumps(data, ensure_ascii=False) + '\n')
                        valid_data_count += 1
                except json.JSONDecodeError as e:
                    errors.append(line)
                    error_log.write(f"Line {line_count}: {line}\n")

    print(f"Total valid data count: {valid_data_count}")
    print(f"Total errors: {len(errors)}")
    return valid_data_count

# 定义文件路径
input_path = 'answer.txt'
output_path = 'test2.json'
error_log_path = 'error_log2.txt'

# 运行提取数据的函数
valid_data_count = extract_data(input_path, output_path, error_log_path)
print(f"Total valid data count: {valid_data_count}")
# Out:
# Total valid data count: 280
# Total errors: 3681
# Total valid data count: 280

# %%
import json

def is_valid_data(data):
    if "entities" not in data:
        return False
    for entity in data["entities"]:
        if "id" not in entity or "label" not in entity or "start_offset" not in entity or "end_offset" not in entity:
            return False
    return True

def process_line(line):
    return line.strip()

def extract_data(input_path, output_path, error_log_path):
    valid_data_count = 0
    line_count = 0
    buffer = ""
    inside_object = False
    errors = []

    with open(input_path, 'r', encoding='utf-8') as infile, open(output_path, 'w', encoding='utf-8') as outfile, open(
            error_log_path, 'w', encoding='utf-8') as error_log:
        for line in infile:
            line_count += 1
            line = process_line(line)

            if not line:
                continue  # 跳过空行

            if line.startswith("{") and not inside_object:
                inside_object = True
                buffer += line
            elif line.startswith("}") and inside_object:
                buffer += line
                inside_object = False
                try:
                    data = json.loads(buffer)
                    if isinstance(data, dict) and is_valid_data(data):
                        outfile.write(json.dumps(data, ensure_ascii=False) + '\n')
                        valid_data_count += 1
                except json.JSONDecodeError as e:
                    errors.append(buffer)
                    error_log.write(f"Line {line_count}: {buffer}\n")
                buffer = ""
            elif inside_object:
                buffer += line
            else:
                try:
                    data = json.loads(line)
                    if isinstance(data, dict) and is_valid_data(data):
                        outfile.write(json.dumps(data, ensure_ascii=False) + '\n')
                        valid_data_count += 1
                except json.JSONDecodeError as e:
                    errors.append(line)
                    error_log.write(f"Line {line_count}: {line}\n")

    print(f"Total valid data count: {valid_data_count}")
    print(f"Total errors: {len(errors)}")
    return valid_data_count

# 定义文件路径
input_path = 'NER.txt'
output_path = 'output_NER.json'
error_log_path = 'log.txt'

# 运行提取数据的函数
valid_data_count = extract_data(input_path, output_path, error_log_path)
print(f"Total valid data count: {valid_data_count}")
# Out:
# Total valid data count: 1
# Total errors: 3859
# Total valid data count: 1

# %%
import re

# 读取文件内容
file_path = 'NER.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    content = file.read()

# 使用正则表达式匹配所有的JSON对象
pattern = re.compile(r'\{.*?\}(?=\n|$)', re.DOTALL)
matches = pattern.findall(content)

# 将匹配到的JSON对象逐行写入新文件
output_file_path = 'extracted_NER.json'
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    for match in matches:
        output_file.write(match.strip() + '\n')

print(f'Extracted {len(matches)} JSON objects to {output_file_path}')
# Out:
# Extracted 1230 JSON objects to extracted_NER.json

# %%
import re
import json

# 读取文件内容
file_path = 'NER.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    content = file.read()

# 使用正则表达式匹配所有的JSON对象，尝试修正未封闭的JSON对象
pattern = re.compile(r'\{.*?\}(?=\n|$)', re.DOTALL)
matches = pattern.findall(content)

# 修正匹配到的JSON对象
corrected_matches = []
for match in matches:
    try:
        json_obj = json.loads(match)  # 检查JSON是否有效
        corrected_matches.append(match.strip())
    except json.JSONDecodeError:
        # 尝试修复JSON对象
        if match.count('{') != match.count('}'):
            match += '}' * (match.count('{') - match.count('}'))
        try:
            json.loads(match)  # 再次检查修复后的JSON
            corrected_matches.append(match.strip())
        except json.JSONDecodeError:
            print(f"Failed to correct JSON object: {match}")

# 将修正后的JSON对象逐行写入新文件
output_file_path = 'extracted_NER.json'
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    for match in corrected_matches:
        output_file.write(match + '\n')

print(f'Extracted {len(corrected_matches)} JSON objects to {output_file_path}')
# Out:
# Failed to correct JSON object: {"id": 1, "text": "第 3 章 个旧锡铜多金属矿床深部成矿地质背景",
# "entities": [
#       {"id": 1, "label": "矿床知识本体", "start_offset": 0, "end_offset": 23, "text": "第 3 章 个旧锡铜多金属矿床深部成矿地质背景"},
#       {"id": 2, "label": "矿床", "start_offset": 6, "end_offset": 15, "text": "个旧锡铜多金属矿床"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "云南个旧锡-铜多金属矿床，位于昆明以南约300km 处，是世界上最大的锡多金属矿床之一(图3-1)。",
#   "entities": [
#     {"id": 1, "label": "矿床", "start_offset": 2, "end_offset": 12, "text": "个旧锡-铜多金属矿床"},
#     {"id": 2, "label": "地理位置、方位、方向等", "start_offset": 15, "end_offset": 20, "text": "昆明"},
#     {"id": 3, "label": "地理位置、方位、方向等", "start_offset": 22, "end_offset": 28, "text": "以南约300km"},
#     {"id": 4, "label": "矿床", "start_offset": 38, "end_offset": 44, "text": "锡多金属矿床"},
#     {"id": 5, "label": "图表", "start_offset": 50, "end_offset": 56, "text": "图3-1"}}
# Failed to correct JSON object: {"id": 1, "text": "矿田面积约1500km², 从北至南分布五座大型锡-铜-铅-锌多金属矿床，分别是马拉格、松树脚、高松、老厂和卡房矿床，包含平均品位为1%的锡矿石 300Mt, 平均品位为2%的铜矿石300Mt, 平均品位为7%的铅+锌矿石400Mt。",
# "entities": [
#       {"id": 1, "label": "矿区位置", "start_offset": 0, "end_offset": 3, "text": "矿田"},
#       {"id": 2, "label": "属性数值(比例)等", "start_offset": 5, "end_offset": 13, "text": "面积约1500km²"},
#       {"id": 3, "label": "地理位置、方位、方向等", "start_offset": 15, "end_offset": 16, "text": "北"},
#       {"id": 4, "label": "地理位置、方位、方向等", "start_offset": 17, "end_offset": 18, "text": "南"},
#       {"id": 5, "label": "矿床", "start_offset": 23, "end_offset": 36, "text": "锡-铜-铅-锌多金属矿床"},
#       {"id": 6, "label": "矿床", "start_offset": 41, "end_offset": 44, "text": "马拉格"},
#       {"id": 7, "label": "矿床", "start_offset": 45, "end_offset": 48, "text": "松树脚"},
#       {"id": 8, "label": "矿床", "start_offset": 49, "end_offset": 51, "text": "高松"},
#       {"id": 9, "label": "矿床", "start_offset": 52, "end_offset": 54, "text": "老厂"},
#       {"id": 10, "label": "矿床", "start_offset": 55, "end_offset": 58, "text": "卡房矿床"},
#       {"id": 11, "label": "品位", "start_offset": 65, "end_offset": 68, "text": "1%"},
#       {"id": 12, "label": "矿石", "start_offset": 69, "end_offset": 72, "text": "锡矿石"},
#       {"id": 13, "label": "储量", "start_offset": 73, "end_offset": 78, "text": "300Mt"},
#       {"id": 14, "label": "品位", "start_offset": 80, "end_offset": 83, "text": "2%"},
#       {"id": 15, "label": "矿石", "start_offset": 84, "end_offset": 87, "text": "铜矿石"},
#       {"id": 16, "label": "储量", "start_offset": 88, "end_offset": 93, "text": "300Mt"},
#       {"id": 17, "label": "品位", "start_offset": 95, "end_offset": 98, "text": "7%"},
#       {"id": 18, "label": "矿石", "start_offset": 99, "end_offset": 105, "text": "铅+锌矿石"},
#       {"id": 19, "label": "储量", "start_offset": 106, "end_offset": 111, "text": "400Mt"}}
# Failed to correct JSON object: {"id": 1, "text": "锡铜多金属矿床围绕花岗岩岩钟普遍发育矽卡岩化蚀变，多个矿化类型和金属分带明显(Cheng et al.2013b) 。",
# "entities": [
#       {"id": 1, "label": "矿床", "start_offset": 0, "end_offset": 7, "text": "锡铜多金属矿床"},
#       {"id": 2, "label": "岩石", "start_offset": 10, "end_offset": 13, "text": "花岗岩"},
#       {"id": 3, "label": "蚀变作用", "start_offset": 19, "end_offset": 25, "text": "矽卡岩化蚀变"},
#       {"id": 4, "label": "矿化作用", "start_offset": 26, "end_offset": 30, "text": "矿化类型"},
#       {"id": 5, "label": "分带序列", "start_offset": 33, "end_offset": 37, "text": "金属分带"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "尽管对矿床成因有争议，但矿床成因被认为主要与晚白垩世花岗岩有关 (308 Geological Party,1984;罗君烈，1995:毛景文等，2008a,2008b; 赵一鸣和李大新，1987;庄永秋等，1996;Cheng&Mao,2010;Cheng et al.,2012a,2012b,2013a. 2013b)。",
#   "entities": [
#     {"id": 1, "label": "地质年代", "start_offset": 27, "end_offset": 32, "text": "晚白垩世"},
#     {"id": 2, "label": "岩石", "start_offset": 32, "end_offset": 35, "text": "花岗岩"},
#     {"id": 3, "label": "部门、人员、研究所、实验室", "start_offset": 38, "end_offset": 58, "text": "308 Geological Party"},
#     {"id": 4, "label": "部门、人员、研究所、实验室", "start_offset": 59, "end_offset": 62, "text": "罗君烈"},
#     {"id": 5, "label": "部门、人员、研究所、实验室", "start_offset": 63, "end_offset": 67, "text": "毛景文"},
#     {"id": 6, "label": "部门、人员、研究所、实验室", "start_offset": 74, "end_offset": 80, "text": "赵一鸣"},
#     {"id": 7, "label": "部门、人员、研究所、实验室", "start_offset": 81, "end_offset": 85, "text": "李大新"},
#     {"id": 8, "label": "部门、人员、研究所、实验室", "start_offset": 87, "end_offset": 91, "text": "庄永秋"},
#     {"id": 9, "label": "部门、人员、研究所、实验室", "start_offset": 92, "end_offset": 96, "text": "Cheng"},
#     {"id": 10, "label": "部门、人员、研究所、实验室", "start_offset": 97, "end_offset": 100, "text": "Mao"},
#     {"id": 11, "label": "部门、人员、研究所、实验室", "start_offset": 101, "end_offset": 106, "text": "Cheng"},
#     {"id": 12, "label": "部门、人员、研究所、实验室", "start_offset": 107, "end_offset": 110, "text": "Mao"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "本书将应用二维经验模分解(bi-dimensional empirical mode decomposition,BEMD)方法，对个旧锡-铜多金属矿床和相邻的薄竹山铅-锌-银多金属矿床1:20万重力数据进行分解和提取重力分量，以揭示与锡-铜多金属矿化相关的深部地质结构和花岗岩体，并为该区深部隐伏矿体勘查提供科学依据。",
#   "entities": [
#     {"id": 1, "label": "方法、程序、原理", "start_offset": 6, "end_offset": 18, "text": "二维经验模分解"},
#     {"id": 2, "label": "方法、程序、原理", "start_offset": 19, "end_offset": 61, "text": "bi-dimensional empirical mode decomposition,BEMD"},
#     {"id": 3, "label": "矿床", "start_offset": 67, "end_offset": 78, "text": "个旧锡-铜多金属矿床"},
#     {"id": 4, "label": "矿床", "start_offset": 84, "end_offset": 100, "text": "薄竹山铅-锌-银多金属矿床"},
#     {"id": 5, "label": "数据", "start_offset": 101, "end_offset": 110, "text": "1:20万重力数据"},
#     {"id": 6, "label": "分量", "start_offset": 118, "end_offset": 122, "text": "重力分量"},
#     {"id": 7, "label": "地质构造/结构", "start_offset": 140, "end_offset": 146, "text": "深部地质结构"},
#     {"id": 8, "label": "岩体", "start_offset": 147, "end_offset": 151, "text": "花岗岩体"},
#     {"id": 9, "label": "矿体", "start_offset": 160, "end_offset": 164, "text": "隐伏矿体"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "3.1  二维经验模分解原理与方法",
#   "entities": [
#     {
#       "id": 1,
#       "label": "副标题",
#       "start_offset": 0,
#       "end_offset": 3,
#       "text": "3.1"
#     },
#     {
#       "id": 2,
#       "label": "方法、程序、原理",
#       "start_offset": 5,
#       "end_offset": 15,
#       "text": "二维经验模分解原理与方法"
#     }}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "为解决这一问题，Huang等建立一种适合的分析非线性和非 平稳数据方法称为Hilbert-Huang变换(HHT),该方法包括经验模分解(EMD)和Hilbert谱分析。",
#   "entities": [
#     {"id": 1, "label": "部门、人员、研究所、实验室", "start_offset": 7, "end_offset": 12, "text": "Huang"},
#     {"id": 2, "label": "方法、程序、原理", "start_offset": 34, "end_offset": 46, "text": "Hilbert-Huang变换(HHT)"},
#     {"id": 3, "label": "方法、程序、原理", "start_offset": 53, "end_offset": 59, "text": "经验模分解(EMD)"},
#     {"id": 4, "label": "方法、程序、原理", "start_offset": 62, "end_offset": 70, "text": "Hilbert谱分析"}}
# Failed to correct JSON object: {"id": 1, "text": "该方法可用于从原始数据集中提取局部异常信息(Huang et al.,1998)。",
# "entities": [
#       {"id": 1, "label": "异常", "start_offset": 17, "end_offset": 23, "text": "局部异常信息"},
#       {"id": 2, "label": "部门、人员、研究所、实验室", "start_offset": 24, "end_offset": 38, "text": "Huang et al.,1998"}}
# Failed to correct JSON object: {"id": 1, "text": "3.2  重力致矿异常信息提取",
# "entities": [
#       {"id": 1, "label": "副标题", "start_offset": 0, "end_offset": 16, "text": "3.2  重力致矿异常信息提取"}}
# Failed to correct JSON object: {"id": 1, "text": "书中所用重力数据来源于云南省地质调查局，其测量网距为2000m×2000m, 其布格重力异常如图3-2所示。",
# "entities": [
#       {"id": 1, "label": "数据", "start_offset": 3, "end_offset": 9, "text": "重力数据"},
#       {"id": 2, "label": "部门、人员、研究所、实验室", "start_offset": 13, "end_offset": 23, "text": "云南省地质调查局"},
#       {"id": 3, "label": "网距", "start_offset": 32, "end_offset": 44, "text": "2000m×2000m"},
#       {"id": 4, "label": "重力异常范围", "start_offset": 49, "end_offset": 55, "text": "布格重力异常"},
#       {"id": 5, "label": "图表", "start_offset": 56, "end_offset": 61, "text": "图3-2"}}
# Failed to correct JSON object: {"id": 1, "text": "该区出露的地质体的密度值范围：花岗岩的密度值为2.55~2.60g/cm³,碳酸盐岩的密度值为2.68～2.72g/cm³, 基性-超基性岩的密度值为2.98~3.10g/cm³, 个旧矿区块状锡矿石的密度值为4.52g/cm³(熊光楚和石盛滕，1994)。",
# "entities": [
#       {"id": 1, "label": "岩石", "start_offset": 17, "end_offset": 20, "text": "花岗岩"},
#       {"id": 2, "label": "岩石密度", "start_offset": 25, "end_offset": 38, "text": "2.55~2.60g/cm³"},
#       {"id": 3, "label": "岩石", "start_offset": 40, "end_offset": 45, "text": "碳酸盐岩"},
#       {"id": 4, "label": "岩石密度", "start_offset": 50, "end_offset": 63, "text": "2.68～2.72g/cm³"},
#       {"id": 5, "label": "岩石", "start_offset": 65, "end_offset": 73, "text": "基性-超基性岩"},
#       {"id": 6, "label": "岩石密度", "start_offset": 78, "end_offset": 91, "text": "2.98~3.10g/cm³"},
#       {"id": 7, "label": "矿区", "start_offset": 93, "end_offset": 97, "text": "个旧矿区"},
#       {"id": 8, "label": "矿石结构/构造", "start_offset": 97, "end_offset": 101, "text": "块状"},
#       {"id": 9, "label": "矿石", "start_offset": 101, "end_offset": 104, "text": "锡矿石"},
#       {"id": 10, "label": "岩石密度", "start_offset": 109, "end_offset": 116, "text": "4.52g/cm³"},
#       {"id": 11, "label": "部门、人员、研究所、实验室", "start_offset": 118, "end_offset": 124, "text": "熊光楚"},
#       {"id": 12, "label": "部门、人员、研究所、实验室", "start_offset": 125, "end_offset": 129, "text": "石盛滕"}}
# Failed to correct JSON object: {"id": 1, "text": "本研究中，设定SD=0.02, 对测量网距为2000m×2000m的重力数据进行分解，据式 ( 3 - 1 ) ,BEMD的筛分过程为：",
# "entities": [
#       {"id": 1, "label": "属性数值(比例)等", "start_offset": 7, "end_offset": 13, "text": "SD=0.02"},
#       {"id": 2, "label": "网距", "start_offset": 19, "end_offset": 32, "text": "2000m×2000m"},
#       {"id": 3, "label": "数据", "start_offset": 35, "end_offset": 39, "text": "重力数据"},
#       {"id": 4, "label": "公式", "start_offset": 48, "end_offset": 55, "text": "式 ( 3 - 1 )"},
#       {"id": 5, "label": "数据统计方法", "start_offset": 56, "end_offset": 60, "text": "BEMD"}}
# Failed to correct JSON object: {"id": 1, "text": "式中：Ori(m,n) 为原始二维重力数据；B(m,n) 为 BIMF 分量；Res(m,n)为二维剩余分量。",
# "entities": [
#       {"id": 1, "label": "数据", "start_offset": 8, "end_offset": 18, "text": "原始二维重力数据"},
#       {"id": 2, "label": "分量", "start_offset": 27, "end_offset": 31, "text": "BIMF 分量"},
#       {"id": 3, "label": "分量", "start_offset": 40, "end_offset": 46, "text": "二维剩余分量"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "研究区混合重力数据在二维空间中可以分解为3个频率依次降低的 BIMF分量 (BIMF₁ 、BIMF₂ 、BIMF₃) 和1个频率最低的剩余分量[Res(m,n)] 。",
#   "entities": [
#     {
#       "id": 1,
#       "label": "数据",
#       "start_offset": 0,
#       "end_offset": 10,
#       "text": "研究区混合重力数据"
#     },
#     {
#       "id": 2,
#       "label": "分量",
#       "start_offset": 32,
#       "end_offset": 38,
#       "text": "BIMF分量"
#     },
#     {
#       "id": 3,
#       "label": "分量",
#       "start_offset": 40,
#       "end_offset": 46,
#       "text": "BIMF₁"
#     },
#     {
#       "id": 4,
#       "label": "分量",
#       "start_offset": 48,
#       "end_offset": 54,
#       "text": "BIMF₂"
#     },
#     {
#       "id": 5,
#       "label": "分量",
#       "start_offset": 56,
#       "end_offset": 62,
#       "text": "BIMF₃"
#     },
#     {
#       "id": 6,
#       "label": "分量",
#       "start_offset": 70,
#       "end_offset": 80,
#       "text": "剩余分量[Res(m,n)]"
#     },
#     {
#       "id": 7,
#       "label": "趋势、数据分布、程度、顺序",
#       "start_offset": 24,
#       "end_offset": 31,
#       "text": "频率依次降低"
#     },
#     {
#       "id": 8,
#       "label": "趋势、数据分布、程度、顺序",
#       "start_offset": 65,
#       "end_offset": 69,
#       "text": "频率最低"
#     }}
# Failed to correct JSON object: {"id": 1, "text": "对个旧锡-铜多金属矿田以互相垂直的AB和CD剖面(见图3-2)实施一维分解(图3-3)。",
# "entities": [
#       {"id": 1, "label": "矿区", "start_offset": 1, "end_offset": 10, "text": "个旧锡-铜多金属矿田"},
#       {"id": 2, "label": "图表", "start_offset": 24, "end_offset": 30, "text": "图3-2"},
#       {"id": 3, "label": "图表", "start_offset": 36, "end_offset": 42, "text": "图3-3"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "对上述两个方向BIMF分量实施正交性检验(表3-1)。",
#   "entities": [
#     {"id": 1, "label": "分量", "start_offset": 9, "end_offset": 15, "text": "BIMF分量"},
#     {"id": 2, "label": "图表", "start_offset": 22, "end_offset": 27, "text": "表3-1"}}
# Failed to correct JSON object: {"id": 1, "text": "结果表明，正交性指数除了IO23值略大于零，IO12和IO13值接近于零，因此基本满足正交性原则。",
# "entities": [
#       {"id": 1, "label": "参数", "start_offset": 6, "end_offset": 11, "text": "正交性指数"},
#       {"id": 2, "label": "参数", "start_offset": 14, "end_offset": 18, "text": "IO23值"},
#       {"id": 3, "label": "趋势、数据分布、程度、顺序", "start_offset": 19, "end_offset": 23, "text": "略大于零"},
#       {"id": 4, "label": "参数", "start_offset": 24, "end_offset": 28, "text": "IO12值"},
#       {"id": 5, "label": "参数", "start_offset": 29, "end_offset": 33, "text": "IO13值"},
#       {"id": 6, "label": "趋势、数据分布、程度、顺序", "start_offset": 34, "end_offset": 38, "text": "接近于零"},
#       {"id": 7, "label": "地图术语、地质术语", "start_offset": 43, "end_offset": 48, "text": "正交性原则"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "3.3  高通滤波重力分量异常与浅层地壳控矿地质结构",
#   "entities": [
#     {
#       "id": 1,
#       "label": "副标题",
#       "start_offset": 0,
#       "end_offset": 2,
#       "text": "3.3"
#     },
#     {
#       "id": 2,
#       "label": "分量",
#       "start_offset": 4,
#       "end_offset": 16,
#       "text": "高通滤波重力分量异常"
#     },
#     {
#       "id": 3,
#       "label": "成/容/控矿构造",
#       "start_offset": 17,
#       "end_offset": 29,
#       "text": "浅层地壳控矿地质结构"
#     }}
# Failed to correct JSON object: {"id": 1, "text": "高通滤波重力分量异常(BIMF₁)反映了研究区浅层地质结构(图3-4)。",
# "entities": [
#       {"id": 1, "label": "分量", "start_offset": 0, "end_offset": 13, "text": "高通滤波重力分量异常(BIMF₁)"},
#       {"id": 2, "label": "地图术语、地质术语", "start_offset": 20, "end_offset": 28, "text": "浅层地质结构"},
#       {"id": 3, "label": "图表", "start_offset": 29, "end_offset": 35, "text": "图3-4"}}
# Failed to correct JSON object: {"id": 1, "text": "3处负重力异常被正重力异常包围，其中2处负重力异常分别对应个旧矿田西部出露花岗岩 (I)和矿田东部隐伏花岗岩(Ⅱ)。",
# "entities": [
#       {"id": 1, "label": "异常", "start_offset": 1, "end_offset": 7, "text": "负重力异常"},
#       {"id": 2, "label": "异常", "start_offset": 8, "end_offset": 14, "text": "正重力异常"},
#       {"id": 3, "label": "异常", "start_offset": 19, "end_offset": 25, "text": "负重力异常"},
#       {"id": 4, "label": "异常", "start_offset": 30, "end_offset": 36, "text": "负重力异常"},
#       {"id": 5, "label": "矿区位置", "start_offset": 39, "end_offset": 45, "text": "个旧矿田西部"},
#       {"id": 6, "label": "岩石", "start_offset": 48, "end_offset": 51, "text": "花岗岩"},
#       {"id": 7, "label": "矿区位置", "start_offset": 56, "end_offset": 62, "text": "矿田东部"},
#       {"id": 8, "label": "岩石", "start_offset": 65, "end_offset": 68, "text": "花岗岩"}}
# Failed to correct JSON object: {"id": 1, "text": "正重力异常 (IV)可能是由基性岩墙和/或锡-铜蚀变矿化矽卡岩充填断层所致。",
# "entities": [
#       {"id": 1, "label": "异常", "start_offset": 0, "end_offset": 6, "text": "正重力异常"},
#       {"id": 2, "label": "岩石", "start_offset": 18, "end_offset": 22, "text": "基性岩墙"},
#       {"id": 3, "label": "矿化状态", "start_offset": 27, "end_offset": 35, "text": "锡-铜蚀变矿化矽卡岩"},
#       {"id": 4, "label": "地质构造/结构", "start_offset": 36, "end_offset": 38, "text": "断层"}}
# Failed to correct JSON object: {"id": 1, "text": "北东向弥勒-师宗断裂北西侧存在1处明显的负重力异常 (Ⅲ),推测可能是由隐伏花岗岩引起的，这可能是勘查锡-铅-锌多金属矿床的新领域。",
# "entities": [
#       {"id": 1, "label": "地质构造/结构", "start_offset": 4, "end_offset": 12, "text": "弥勒-师宗断裂"},
#       {"id": 2, "label": "地理位置、方位、方向等", "start_offset": 0, "end_offset": 3, "text": "北东向"},
#       {"id": 3, "label": "地理位置、方位、方向等", "start_offset": 13, "end_offset": 16, "text": "北西侧"},
#       {"id": 4, "label": "异常", "start_offset": 23, "end_offset": 29, "text": "负重力异常"},
#       {"id": 5, "label": "岩石", "start_offset": 42, "end_offset": 45, "text": "花岗岩"},
#       {"id": 6, "label": "矿床", "start_offset": 55, "end_offset": 64, "text": "锡-铅-锌多金属矿床"},
#       {"id": 7, "label": "矿床类别", "start_offset": 65, "end_offset": 68, "text": "新领域"}}
# Failed to correct JSON object: {"id": 1, "text": "在个旧锡-铜多金属矿田，从北到南绘制了地质-地球物理剖面图(图3-5,其剖面位置见图3-2 中的A-A')。",
# "entities": [
#       {"id": 1, "label": "矿区", "start_offset": 1, "end_offset": 10, "text": "个旧锡-铜多金属矿田"},
#       {"id": 2, "label": "地理位置、方位、方向等", "start_offset": 12, "end_offset": 13, "text": "北"},
#       {"id": 3, "label": "地理位置、方位、方向等", "start_offset": 14, "end_offset": 15, "text": "南"},
#       {"id": 4, "label": "图表", "start_offset": 27, "end_offset": 32, "text": "图3-5"},
#       {"id": 5, "label": "图表", "start_offset": 41, "end_offset": 46, "text": "图3-2"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "图3-5 表 明 了BIMF1重力分量异常与原始重力异常沿地质剖面的变化：BMF1重力分量异常比原始重力异常和利用SVD分解的局部重力分量异常(SVD)(Chen  et  al.,2015)更精确地刻画了隐伏花岗岩及其接触交代矽卡岩蚀变和锡-铜多金属矿化的形态变化。",
#   "entities": [
#     {"id": 1, "label": "图表", "start_offset": 0, "end_offset": 4, "text": "图3-5"},
#     {"id": 2, "label": "分量", "start_offset": 10, "end_offset": 20, "text": "BIMF1重力分量异常"},
#     {"id": 3, "label": "分量", "start_offset": 25, "end_offset": 31, "text": "原始重力异常"},
#     {"id": 4, "label": "分量", "start_offset": 38, "end_offset": 44, "text": "BMF1重力分量异常"},
#     {"id": 5, "label": "分量", "start_offset": 47, "end_offset": 53, "text": "原始重力异常"},
#     {"id": 6, "label": "分量", "start_offset": 56, "end_offset": 74, "text": "利用SVD分解的局部重力分量异常"},
#     {"id": 7, "label": "岩石", "start_offset": 97, "end_offset": 100, "text": "花岗岩"},
#     {"id": 8, "label": "蚀变作用", "start_offset": 104, "end_offset": 110, "text": "接触交代矽卡岩蚀变"},
#     {"id": 9, "label": "矿化状态", "start_offset": 111, "end_offset": 120, "text": "锡-铜多金属矿化"},
#     {"id": 10, "label": "地图术语、地质术语", "start_offset": 121, "end_offset": 125, "text": "形态变化"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "BIMF1重力分量异常值从马拉格锡-铜矿段到松树脚锡-铅矿段变化范围为-3.0～+2.5μm/s², 与上覆碳酸盐岩厚度的增加相吻合；而从松树脚锡-铅矿段到卡房铜-锡矿段，BIMF1重力分量异常值为-5.5～+2.5μm/s² 。",
#   "entities": [
#     {"id": 1, "label": "分量", "start_offset": 0, "end_offset": 10, "text": "BIMF1重力分量"},
#     {"id": 2, "label": "矿段", "start_offset": 15, "end_offset": 24, "text": "马拉格锡-铜矿段"},
#     {"id": 3, "label": "矿段", "start_offset": 25, "end_offset": 34, "text": "松树脚锡-铅矿段"},
#     {"id": 4, "label": "重力异常范围", "start_offset": 38, "end_offset": 50, "text": "-3.0～+2.5μm/s²"},
#     {"id": 5, "label": "岩石", "start_offset": 55, "end_offset": 61, "text": "碳酸盐岩"},
#     {"id": 6, "label": "地物化条件/特征", "start_offset": 62, "end_offset": 64, "text": "厚度"},
#     {"id": 7, "label": "矿段", "start_offset": 73, "end_offset": 82, "text": "松树脚锡-铅矿段"},
#     {"id": 8, "label": "矿段", "start_offset": 83, "end_offset": 91, "text": "卡房铜-锡矿段"},
#     {"id": 9, "label": "重力异常范围", "start_offset": 96, "end_offset": 108, "text": "-5.5～+2.5μm/s²"}}
# Failed to correct JSON object: {"id": 1, "text": "BIMF1重力分量异常值南端部分从-5.5μm/s²增加到-2.0μm/s², 与上覆碳酸盐岩增厚是一致的。",
# "entities": [
#       {"id": 1, "label": "分量", "start_offset": 0, "end_offset": 9, "text": "BIMF1重力分量异常"},
#       {"id": 2, "label": "地理位置、方位、方向等", "start_offset": 12, "end_offset": 14, "text": "南端"},
#       {"id": 3, "label": "重力异常范围", "start_offset": 18, "end_offset": 26, "text": "-5.5μm/s²"},
#       {"id": 4, "label": "重力异常范围", "start_offset": 30, "end_offset": 37, "text": "-2.0μm/s²"},
#       {"id": 5, "label": "岩石", "start_offset": 42, "end_offset": 48, "text": "上覆碳酸盐岩"},
#       {"id": 6, "label": "地物化条件/特征", "start_offset": 49, "end_offset": 51, "text": "增厚"}}
# Failed to correct JSON object: {"id": 13, "text": "其结果表明，局部重力异常的变化可能主要受花岗杂岩体和上覆碳酸盐岩的厚度，以及局部矿化作用的形态变化影响。",
# "entities": [
#       {"id": 1, "label": "异常", "start_offset": 6, "end_offset": 12, "text": "局部重力异常"},
#       {"id": 2, "label": "岩体", "start_offset": 20, "end_offset": 25, "text": "花岗杂岩体"},
#       {"id": 3, "label": "岩石", "start_offset": 26, "end_offset": 32, "text": "碳酸盐岩"},
#       {"id": 4, "label": "地物化条件/特征", "start_offset": 33, "end_offset": 35, "text": "厚度"},
#       {"id": 5, "label": "矿化作用", "start_offset": 38, "end_offset": 44, "text": "局部矿化作用"},
#       {"id": 6, "label": "地图术语、地质术语", "start_offset": 45, "end_offset": 49, "text": "形态变化"}}
# Failed to correct JSON object: {"id": 1, "text": "3.4  带通滤波重力分量异常与深层地壳控矿地质结构",
# "entities": [
#       {"id": 1, "label": "副标题", "start_offset": 0, "end_offset": 3, "text": "3.4"},
#       {"id": 2, "label": "分量", "start_offset": 5, "end_offset": 17, "text": "带通滤波重力分量异常"},
#       {"id": 3, "label": "成/容/控矿构造", "start_offset": 18, "end_offset": 30, "text": "深层地壳控矿地质结构"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "带通滤波重力分量异常BIMF2图像(图3-6)反映了中-浅层地质结构，存在1个负重力异常集中区域，可能反映了个旧花岗杂岩体的总体分布，包括出露和隐伏花岗岩。",
#   "entities": [
#     {"id": 1, "label": "分量", "start_offset": 0, "end_offset": 13, "text": "带通滤波重力分量异常BIMF2"},
#     {"id": 2, "label": "图表", "start_offset": 15, "end_offset": 21, "text": "图像(图3-6)"},
#     {"id": 3, "label": "地质构造/结构", "start_offset": 25, "end_offset": 33, "text": "中-浅层地质结构"},
#     {"id": 4, "label": "异常", "start_offset": 38, "end_offset": 44, "text": "负重力异常"},
#     {"id": 5, "label": "区域，矿集区", "start_offset": 49, "end_offset": 53, "text": "集中区域"},
#     {"id": 6, "label": "岩体", "start_offset": 61, "end_offset": 67, "text": "个旧花岗杂岩体"},
#     {"id": 7, "label": "地物化条件/特征", "start_offset": 70, "end_offset": 74, "text": "总体分布"},
#     {"id": 8, "label": "岩石", "start_offset": 80, "end_offset": 83, "text": "花岗岩"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "个旧矿田西部的以个旧断裂为界出露的花岗岩，可能向下扩展到个旧矿田的东部，这已被钴井和采矿工程所证实 (Cheng et al.,2012b)。",
#   "entities": [
#     {"id": 1, "label": "矿区位置", "start_offset": 0, "end_offset": 6, "text": "个旧矿田西部"},
#     {"id": 2, "label": "地质构造/结构", "start_offset": 9, "end_offset": 13, "text": "个旧断裂"},
#     {"id": 3, "label": "岩石", "start_offset": 19, "end_offset": 22, "text": "花岗岩"},
#     {"id": 4, "label": "矿区位置", "start_offset": 35, "end_offset": 41, "text": "个旧矿田的东部"},
#     {"id": 5, "label": "部门、人员、研究所、实验室", "start_offset": 48, "end_offset": 50, "text": "钴井"},
#     {"id": 6, "label": "部门、人员、研究所、实验室", "start_offset": 51, "end_offset": 55, "text": "采矿工程"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "另一个带通滤波重力分量异常 BIMF₃图像(图3-7)反映了较低的中层地质结构，存在1个东西向负重力异常区I,异常区I又存在2个负重力异常中心Ia和Ib,分别与个旧锡-铜多金属矿田和薄竹山银-铅-锌多金属矿田对应 (Liu et al.,2007;Cheng&Mao,2010)。",
#   "entities": [
#     {"id": 1, "label": "分量", "start_offset": 3, "end_offset": 15, "text": "带通滤波重力分量异常"},
#     {"id": 2, "label": "图表", "start_offset": 21, "end_offset": 27, "text": "图3-7"},
#     {"id": 3, "label": "趋势、数据分布、程度、顺序", "start_offset": 30, "end_offset": 32, "text": "较低"},
#     {"id": 4, "label": "地图术语、地质术语", "start_offset": 33, "end_offset": 41, "text": "中层地质结构"},
#     {"id": 5, "label": "异常", "start_offset": 46, "end_offset": 52, "text": "负重力异常区"},
#     {"id": 6, "label": "地理位置、方位、方向等", "start_offset": 42, "end_offset": 45, "text": "东西向"},
#     {"id": 7, "label": "异常", "start_offset": 66, "end_offset": 72, "text": "负重力异常中心"},
#     {"id": 8, "label": "矿区", "start_offset": 82, "end_offset": 91, "text": "个旧锡-铜多金属矿田"},
#     {"id": 9, "label": "矿区", "start_offset": 94, "end_offset": 105, "text": "薄竹山银-铅-锌多金属矿田"},
#     {"id": 10, "label": "部门、人员、研究所、实验室", "start_offset": 108, "end_offset": 112, "text": "Liu"},
#     {"id": 11, "label": "部门、人员、研究所、实验室", "start_offset": 118, "end_offset": 122, "text": "Cheng"},
#     {"id": 12, "label": "部门、人员、研究所、实验室", "start_offset": 123, "end_offset": 126, "text": "Mao"}}
# Failed to correct JSON object: {"id": 1, "text": "这说明在研究区中低深度可能存在东西向花岗岩带。",
# "entities": [
#       {"id": 1, "label": "地理位置、方位、方向等", "start_offset": 16, "end_offset": 18, "text": "东西"},
#       {"id": 2, "label": "岩石带", "start_offset": 19, "end_offset": 23, "text": "花岗岩带"}}
# Failed to correct JSON object: {"id": 1, "text": "个旧锡-铜多金属矿田与薄竹山银-铅-锌-锡多金属矿田通过这个花岗岩带相连，形成一个与花岗岩带有关的东西向的区域多金属成矿带(图3-7)。",
# "entities": [
#       {"id": 1, "label": "矿区", "start_offset": 0, "end_offset": 10, "text": "个旧锡-铜多金属矿田"},
#       {"id": 2, "label": "矿区", "start_offset": 11, "end_offset": 26, "text": "薄竹山银-铅-锌-锡多金属矿田"},
#       {"id": 3, "label": "岩石带", "start_offset": 30, "end_offset": 35, "text": "花岗岩带"},
#       {"id": 4, "label": "岩石带", "start_offset": 48, "end_offset": 53, "text": "花岗岩带"},
#       {"id": 5, "label": "地理位置、方位、方向等", "start_offset": 56, "end_offset": 58, "text": "东西"},
#       {"id": 6, "label": "区域，矿集区", "start_offset": 59, "end_offset": 62, "text": "区域"},
#       {"id": 7, "label": "成矿带", "start_offset": 63, "end_offset": 71, "text": "多金属成矿带"},
#       {"id": 8, "label": "图表", "start_offset": 72, "end_offset": 78, "text": "图3-7"}}
# Failed to correct JSON object: {"id": 1, "text": "3.5  低通滤波重力分量异常与壳幔凸凹控矿地质结构",
# "entities": [
#       {"id": 1, "label": "副标题", "start_offset": 0, "end_offset": 3, "text": "3.5"},
#       {"id": 2, "label": "分量", "start_offset": 5, "end_offset": 17, "text": "低通滤波重力分量异常"},
#       {"id": 3, "label": "成/容/控矿构造", "start_offset": 18, "end_offset": 30, "text": "壳幔凸凹控矿地质结构"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "研究区剩余重力异常剩余分量Res(m,n)图像(图3 - 8)反映研究区存在一对北西向正的和负的重力异常区(I和Ⅱ)。",
#   "entities": [
#     {"id": 1, "label": "异常", "start_offset": 4, "end_offset": 10, "text": "剩余重力异常"},
#     {"id": 2, "label": "分量", "start_offset": 11, "end_offset": 22, "text": "剩余分量Res(m,n)"},
#     {"id": 3, "label": "图表", "start_offset": 25, "end_offset": 31, "text": "图3 - 8"},
#     {"id": 4, "label": "地理位置、方位、方向等", "start_offset": 40, "end_offset": 43, "text": "北西"},
#     {"id": 5, "label": "异常", "start_offset": 46, "end_offset": 48, "text": "正的"},
#     {"id": 6, "label": "异常", "start_offset": 51, "end_offset": 53, "text": "负的"},
#     {"id": 7, "label": "异常", "start_offset": 54, "end_offset": 60, "text": "重力异常区"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "空间上，正重力异常区(I)的轴线与哀牢山-红 河断裂基本一致，哀牢山-红河断裂被认为是印支地块和华夏地块之间的边界(Wang et al.,2000;Harison  et  al.,1992;Leloup et al.,1995;Gilley  et  al.,2003;Zhang  et  al., 2006),哀牢山-红河断裂切穿了地壳控制了侵入岩和相关矿化的区域分布(Tran et  al., 2014;Liu et al.,2015),这可能导致地幔和/或基底的隆起形成明显的正重力异常(Kane& Godson,1985;Zeng et al.,1997;Chen et al.,2015)。",
#   "entities": [
#     {"id": 1, "label": "异常", "start_offset": 4, "end_offset": 10, "text": "正重力异常区"},
#     {"id": 2, "label": "地质构造/结构", "start_offset": 18, "end_offset": 28, "text": "哀牢山-红河断裂"},
#     {"id": 3, "label": "地质构造/结构", "start_offset": 34, "end_offset": 44, "text": "哀牢山-红河断裂"},
#     {"id": 4, "label": "区域，矿集区", "start_offset": 49, "end_offset": 54, "text": "印支地块"},
#     {"id": 5, "label": "区域，矿集区", "start_offset": 55, "end_offset": 60, "text": "华夏地块"},
#     {"id": 6, "label": "地质构造/结构", "start_offset": 67, "end_offset": 77, "text": "哀牢山-红河断裂"},
#     {"id": 7, "label": "地质构造/结构", "start_offset": 90, "end_offset": 92, "text": "地壳"},
#     {"id": 8, "label": "岩石", "start_offset": 97, "end_offset": 100, "text": "侵入岩"},
#     {"id": 9, "label": "矿化作用", "start_offset": 101, "end_offset": 103, "text": "矿化"},
#     {"id": 10, "label": "区域，矿集区", "start_offset": 104, "end_offset": 108, "text": "区域分布"},
#     {"id": 11, "label": "地质构造/结构", "start_offset": 113, "end_offset": 118, "text": "地幔"},
#     {"id": 12, "label": "地质构造/结构", "start_offset": 119, "end_offset": 121, "text": "基底"},
#     {"id": 13, "label": "地质构造/结构", "start_offset": 122, "end_offset": 124, "text": "隆起"},
#     {"id": 14, "label": "异常", "start_offset": 126, "end_offset": 132, "text": "正重力异常"}}
# Failed to correct JSON object: {"id": 1, "text": "据推断，正重力异常带与地幔和/ 或基底隆起有关，而负重力区与地幔和/或基底凹陷相联系(Kane&Godson,1985;Zeng et al.,1997;Shah et al.,2013;Chen et al.,2015)。",
# "entities": [
#       {"id": 1, "label": "异常", "start_offset": 5, "end_offset": 11, "text": "正重力异常带"},
#       {"id": 2, "label": "地质构造/结构", "start_offset": 12, "end_offset": 18, "text": "地幔和/ 或基底隆起"},
#       {"id": 3, "label": "异常", "start_offset": 23, "end_offset": 28, "text": "负重力区"},
#       {"id": 4, "label": "地质构造/结构", "start_offset": 29, "end_offset": 35, "text": "地幔和/或基底凹陷"}}
# Failed to correct JSON object: {"id": 1, "text": "个旧锡-铜多金属矿田和相关的花岗岩位于地幔和/或基底隆起一侧(Ⅲ),花岗岩87Sr/86Sr初始比值分布从0.7097 到0.7130,这表明个旧花岗质杂岩体具有壳-幔混合来源的特征(Cheng et al.,2013a);   而位于地幔和/或基底凹陷(Ⅱ)薄竹山银-铅-锌多金属矿床和相关的花岗岩的87Sr/86Sr:初始比值分布从0.7126到0.7170,这表明薄竹山花岗质杂岩体具有壳源花岗岩的特征。",
# "entities": [
#     {"id": 1, "label": "矿田", "start_offset": 0, "end_offset": 10, "text": "个旧锡-铜多金属矿田"},
#     {"id": 2, "label": "岩石", "start_offset": 15, "end_offset": 18, "text": "花岗岩"},
#     {"id": 3, "label": "地质构造/结构", "start_offset": 21, "end_offset": 32, "text": "地幔和/或基底隆起"},
#     {"id": 4, "label": "属性：数值(比例)等", "start_offset": 45, "end_offset": 50, "text": "0.7097"},
#     {"id": 5, "label": "属性：数值(比例)等", "start_offset": 54, "end_offset": 59, "text": "0.7130"},
#     {"id": 6, "label": "岩体", "start_offset": 66, "end_offset": 75, "text": "个旧花岗质杂岩体"},
#     {"id": 7, "label": "成矿条件特点", "start_offset": 78, "end_offset": 86, "text": "壳-幔混合来源"},
#     {"id": 8, "label": "部门、人员、研究所、实验室", "start_offset": 89, "end_offset": 105, "text": "Cheng et al.,2013a"},
#     {"id": 9, "label": "地质构造/结构", "start_offset": 113, "end_offset": 124, "text": "地幔和/或基底凹陷"},
#     {"id": 10, "label": "矿床", "start_offset": 128, "end_offset": 139, "text": "薄竹山银-铅-锌多金属矿床"},
#     {"id": 11, "label": "岩石", "start_offset": 144, "end_offset": 147, "text": "花岗岩"},
#     {"id": 12, "label": "属性：数值(比例)等", "start_offset": 150, "end_offset": 155, "text": "0.7126"},
#     {"id": 13, "label": "属性：数值(比例)等", "start_offset": 159, "end_offset": 164, "text": "0.7170"},
#     {"id": 14, "label": "岩体", "start_offset": 171, "end_offset": 180, "text": "薄竹山花岗质杂岩体"},
#     {"id": 15, "label": "成矿条件特点", "start_offset": 183, "end_offset": 189, "text": "壳源花岗岩"}}
# Failed to correct JSON object: {"id": 1, "text": "这种差异性可能是导致大量锡和铜聚集在个旧锡-铜多金属矿田，而银、铅和锌矿床主要集中在薄竹山成矿的关键因素。",
# "entities": [
#       {"id": 1, "label": "矿床", "start_offset": 20, "end_offset": 31, "text": "个旧锡-铜多金属矿田"},
#       {"id": 2, "label": "矿床", "start_offset": 38, "end_offset": 41, "text": "银、铅和锌矿床"},
#       {"id": 3, "label": "矿区", "start_offset": 45, "end_offset": 49, "text": "薄竹山"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "(1)高通滤波重力分量异常(BIMF1)反映了个旧锡-铜多金属矿田的浅层地质结构，这表明具正重力异常的矽卡岩蚀变和锡-铜矿化分布在具负重力异常的花岗岩周围。",
#   "entities": [
#     {"id": 1, "label": "分量", "start_offset": 3, "end_offset": 17, "text": "高通滤波重力分量异常(BIMF1)"},
#     {"id": 2, "label": "矿区", "start_offset": 22, "end_offset": 34, "text": "个旧锡-铜多金属矿田"},
#     {"id": 3, "label": "地质构造/结构", "start_offset": 37, "end_offset": 43, "text": "浅层地质结构"},
#     {"id": 4, "label": "异常", "start_offset": 49, "end_offset": 55, "text": "正重力异常"},
#     {"id": 5, "label": "蚀变作用", "start_offset": 58, "end_offset": 62, "text": "矽卡岩蚀变"},
#     {"id": 6, "label": "矿化状态", "start_offset": 65, "end_offset": 71, "text": "锡-铜矿化"},
#     {"id": 7, "label": "异常", "start_offset": 77, "end_offset": 83, "text": "负重力异常"},
#     {"id": 8, "label": "岩石", "start_offset": 84, "end_offset": 87, "text": "花岗岩"}}
# Failed to correct JSON object: {"id": 1, "text": "(2)带通滤波重力分量异常(BIMF2)反映了中-浅层地质结构，以个旧断裂为界的个旧矿田西区出露的花岗岩可能在地下深部延伸到了个旧矿田东区，从而形成了一个完整的花岗质杂岩体。",
# "entities": [
#       {"id": 1, "label": "分量", "start_offset": 3, "end_offset": 17, "text": "带通滤波重力分量异常(BIMF2)"},
#       {"id": 2, "label": "地质构造/结构", "start_offset": 28, "end_offset": 34, "text": "地质结构"},
#       {"id": 3, "label": "地质构造/结构", "start_offset": 37, "end_offset": 41, "text": "个旧断裂"},
#       {"id": 4, "label": "矿区位置", "start_offset": 45, "end_offset": 50, "text": "个旧矿田西区"},
#       {"id": 5, "label": "岩石", "start_offset": 54, "end_offset": 57, "text": "花岗岩"},
#       {"id": 6, "label": "岩体部位", "start_offset": 61, "end_offset": 65, "text": "地下深部"},
#       {"id": 7, "label": "矿区位置", "start_offset": 69, "end_offset": 74, "text": "个旧矿田东区"},
#       {"id": 8, "label": "岩体", "start_offset": 82, "end_offset": 89, "text": "花岗质杂岩体"}}
# Failed to correct JSON object: {
#   "id": 3,
#   "text": "(3)另一个带通滤波重力分量异常(BIMF3)反映了较低的中下层地质结构，其表明在研究区中下部可能存在一东西向相连的个旧锡-铜多金属矿田与薄竹山银-铅-锌-锡多金属矿田的花岗岩带，进而推测在研究区可能内存在一条与东西向花岗岩带相关联的区域多金属成矿带。",
#   "entities": [
#     {"id": 1, "label": "分量", "start_offset": 6, "end_offset": 22, "text": "带通滤波重力分量异常(BIMF3)"},
#     {"id": 2, "label": "趋势、数据分布、程度、顺序", "start_offset": 25, "end_offset": 27, "text": "较低"},
#     {"id": 3, "label": "地图术语、地质术语", "start_offset": 28, "end_offset": 36, "text": "中下层地质结构"},
#     {"id": 4, "label": "矿区", "start_offset": 66, "end_offset": 74, "text": "个旧锡-铜多金属矿田"},
#     {"id": 5, "label": "矿区", "start_offset": 75, "end_offset": 87, "text": "薄竹山银-铅-锌-锡多金属矿田"},
#     {"id": 6, "label": "岩石带", "start_offset": 88, "end_offset": 93, "text": "花岗岩带"},
#     {"id": 7, "label": "区域，矿集区", "start_offset": 108, "end_offset": 112, "text": "研究区"},
#     {"id": 8, "label": "成矿带", "start_offset": 129, "end_offset": 135, "text": "区域多金属成矿带"},
#     {"id": 9, "label": "岩石带", "start_offset": 123, "end_offset": 128, "text": "花岗岩带"}}
# Failed to correct JSON object: {"id": 1, "text": "(4)低通滤波重力分量异常[Res(m,n)]可能反映了研究区的深部地质结构特征，北西向正重力异常可能反映地幔和/或基岩隆起区，北西向负重力异常可能反映地幔和/或基岩的凹陷区。",
# "entities": [
#       {"id": 1, "label": "分量", "start_offset": 3, "end_offset": 18, "text": "低通滤波重力分量异常[Res(m,n)]"},
#       {"id": 2, "label": "地图术语、地质术语", "start_offset": 27, "end_offset": 35, "text": "深部地质结构特征"},
#       {"id": 3, "label": "异常", "start_offset": 36, "end_offset": 42, "text": "正重力异常"},
#       {"id": 4, "label": "地质构造/结构", "start_offset": 45, "end_offset": 51, "text": "地幔"},
#       {"id": 5, "label": "地质构造/结构", "start_offset": 52, "end_offset": 54, "text": "基岩"},
#       {"id": 6, "label": "地质构造/结构", "start_offset": 55, "end_offset": 59, "text": "隆起区"},
#       {"id": 7, "label": "异常", "start_offset": 60, "end_offset": 66, "text": "负重力异常"},
#       {"id": 8, "label": "地质构造/结构", "start_offset": 69, "end_offset": 75, "text": "地幔"},
#       {"id": 9, "label": "地质构造/结构", "start_offset": 76, "end_offset": 78, "text": "基岩"},
#       {"id": 10, "label": "地质构造/结构", "start_offset": 79, "end_offset": 83, "text": "凹陷区"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "个旧锡-铜多金属矿床和相关的花岗岩位于两者的过渡带靠近隆起一侧，而薄竹山银-铅-锌多金属矿床和相关的花岗岩位于其凹陷区内，这说明深部壳-幔相互作用的复杂性控制了研究区内燕山晚期花岗岩和相关的多金属矿床成矿的多样性。",
#   "entities": [
#     {"id": 1, "label": "矿床", "start_offset": 0, "end_offset": 10, "text": "个旧锡-铜多金属矿床"},
#     {"id": 2, "label": "岩石", "start_offset": 14, "end_offset": 17, "text": "花岗岩"},
#     {"id": 3, "label": "矿床", "start_offset": 28, "end_offset": 38, "text": "薄竹山银-铅-锌多金属矿床"},
#     {"id": 4, "label": "岩石", "start_offset": 42, "end_offset": 45, "text": "花岗岩"},
#     {"id": 5, "label": "地物化条件/特征", "start_offset": 64, "end_offset": 67, "text": "凹陷区"},
#     {"id": 6, "label": "作用方式", "start_offset": 74, "end_offset": 80, "text": "壳-幔相互作用"},
#     {"id": 7, "label": "地质年代", "start_offset": 95, "end_offset": 100, "text": "燕山晚期"},
#     {"id": 8, "label": "岩石", "start_offset": 101, "end_offset": 104, "text": "花岗岩"},
#     {"id": 9, "label": "矿床", "start_offset": 109, "end_offset": 115, "text": "多金属矿床"},
#     {"id": 10, "label": "成矿特点", "start_offset": 116, "end_offset": 122, "text": "成矿的多样性"}}
# Failed to correct JSON object: {"id": 1, "text": "第 4 章 个旧花岗质岩石及其形成的地球动力学环境",
# "entities": [
#       {"id": 1, "label": "矿床知识本体", "start_offset": 0, "end_offset": 25, "text": "第 4 章 个旧花岗质岩石及其形成的地球动力学环境"},
#       {"id": 2, "label": "岩石", "start_offset": 6, "end_offset": 12, "text": "花岗质岩石"}}
# Failed to correct JSON object: {"id": 1, "text": "花岗质岩石在个旧地区广泛分布，且在个旧超大型锡-铜多金属矿床成矿作用过程中扮演重要角色。",
# "entities": [
#       {"id": 1, "label": "岩石", "start_offset": 0, "end_offset": 5, "text": "花岗质岩石"},
#       {"id": 2, "label": "地理位置、方位、方向等", "start_offset": 6, "end_offset": 10, "text": "个旧地区"},
#       {"id": 3, "label": "矿床", "start_offset": 17, "end_offset": 30, "text": "个旧超大型锡-铜多金属矿床"},
#       {"id": 4, "label": "矿化作用", "start_offset": 31, "end_offset": 35, "text": "成矿作用"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "4.1  岩石学与地球化学特征",
#   "entities": [
#     {
#       "id": 1,
#       "label": "副标题",
#       "start_offset": 0,
#       "end_offset": 2,
#       "text": "4.1"
#     },
#     {
#       "id": 2,
#       "label": "地图术语、地质术语",
#       "start_offset": 4,
#       "end_offset": 14,
#       "text": "岩石学"
#     },
#     {
#       "id": 3,
#       "label": "地图术语、地质术语",
#       "start_offset": 15,
#       "end_offset": 23,
#       "text": "地球化学"
#     },
#     {
#       "id": 4,
#       "label": "地图术语、地质术语",
#       "start_offset": 24,
#       "end_offset": 26,
#       "text": "特征"
#     }}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "4.1.1   岩石学特征",
#   "entities": [
#     {
#       "id": 1,
#       "label": "副标题",
#       "start_offset": 0,
#       "end_offset": 6,
#       "text": "4.1.1"
#     },
#     {
#       "id": 2,
#       "label": "地图术语、地质术语",
#       "start_offset": 9,
#       "end_offset": 14,
#       "text": "岩石学特征"
#     }}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "根据岩石结构特征，可将个旧地区花岗质岩石分为斑状花岗岩和等粒花岗岩：①斑状花岗岩包括龙岔河岩体、马拉格—松树脚岩体、北炮台和老厂岩体以及贾沙斑状石英二长岩体；②等粒花岗岩包括白沙冲、老厂—卡房、神仙水、高峰山和新山岩体。",
#   "entities": [
#     {"id": 1, "label": "岩石结构", "start_offset": 2, "end_offset": 8, "text": "岩石结构"},
#     {"id": 2, "label": "区域，矿集区", "start_offset": 14, "end_offset": 18, "text": "个旧地区"},
#     {"id": 3, "label": "岩石", "start_offset": 19, "end_offset": 25, "text": "花岗质岩石"},
#     {"id": 4, "label": "岩石", "start_offset": 28, "end_offset": 34, "text": "斑状花岗岩"},
#     {"id": 5, "label": "岩石", "start_offset": 35, "end_offset": 41, "text": "等粒花岗岩"},
#     {"id": 6, "label": "岩石", "start_offset": 44, "end_offset": 50, "text": "斑状花岗岩"},
#     {"id": 7, "label": "岩体", "start_offset": 53, "end_offset": 58, "text": "龙岔河岩体"},
#     {"id": 8, "label": "岩体", "start_offset": 59, "end_offset": 70, "text": "马拉格—松树脚岩体"},
#     {"id": 9, "label": "岩体", "start_offset": 71, "end_offset": 74, "text": "北炮台"},
#     {"id": 10, "label": "岩体", "start_offset": 75, "end_offset": 80, "text": "老厂岩体"},
#     {"id": 11, "label": "岩体", "start_offset": 83, "end_offset": 94, "text": "贾沙斑状石英二长岩体"},
#     {"id": 12, "label": "岩石", "start_offset": 97, "end_offset": 103, "text": "等粒花岗岩"},
#     {"id": 13, "label": "岩体", "start_offset": 106, "end_offset": 110, "text": "白沙冲"},
#     {"id": 14, "label": "岩体", "start_offset": 111, "end_offset": 118, "text": "老厂—卡房"},
#     {"id": 15, "label": "岩体", "start_offset": 119, "end_offset": 122, "text": "神仙水"},
#     {"id": 16, "label": "岩体", "start_offset": 123, "end_offset": 127, "text": "高峰山"},
#     {"id": 17, "label": "岩体", "start_offset": 128, "end_offset": 131, "text": "新山岩体"}}
# Failed to correct JSON object: {"id": 1, "text": "此外，还有贾沙杂岩体、含铁镁质微粒细晶包体的贾沙花岗岩、白云山-长岭岗碱性岩。",
# "entities": [
#       {"id": 1, "label": "岩体", "start_offset": 6, "end_offset": 12, "text": "贾沙杂岩体"},
#       {"id": 2, "label": "岩石", "start_offset": 19, "end_offset": 30, "text": "含铁镁质微粒细晶包体的贾沙花岗岩"},
#       {"id": 3, "label": "岩石", "start_offset": 31, "end_offset": 42, "text": "白云山-长岭岗碱性岩"}}
# Failed to correct JSON object: {"id": 1, "text": "这些岩体在西区有很好的出露，在东区多深埋地下，仅在马拉格和北炮台有零星出露(图4-1; Cheng,2013a,b)。",
# "entities": [
#       {"id": 1, "label": "岩体", "start_offset": 2, "end_offset": 4, "text": "岩体"},
#       {"id": 2, "label": "矿区位置", "start_offset": 5, "end_offset": 7, "text": "西区"},
#       {"id": 3, "label": "矿区位置", "start_offset": 18, "end_offset": 20, "text": "东区"},
#       {"id": 4, "label": "矿段", "start_offset": 30, "end_offset": 33, "text": "马拉格"},
#       {"id": 5, "label": "矿区", "start_offset": 34, "end_offset": 37, "text": "北炮台"},
#       {"id": 6, "label": "图表", "start_offset": 44, "end_offset": 50, "text": "图4-1"}}
# Failed to correct JSON object: {"id": 1, "text": "斑状花岗岩(以北炮台斑状黑云母花岗岩为例),呈灰白色，具似斑状中粒花岗结构。",
# "entities": [
#       {"id": 1, "label": "岩石", "start_offset": 0, "end_offset": 6, "text": "斑状花岗岩"},
#       {"id": 2, "label": "岩石", "start_offset": 8, "end_offset": 21, "text": "北炮台斑状黑云母花岗岩"},
#       {"id": 3, "label": "颜色", "start_offset": 25, "end_offset": 28, "text": "灰白色"},
#       {"id": 4, "label": "岩石结构", "start_offset": 31, "end_offset": 40, "text": "似斑状中粒花岗结构"}}
# Failed to correct JSON object: {"id": 1, "text": "主要造岩矿物包括碱性长石(32%)、斜长石(30%)、石英(25%)、黑云母 (8%);副矿物约占5%，其中包括磁铁矿、钛铁矿、榍石、褐帘石、锆石和独居石。",
# "entities": [
#       {"id": 1, "label": "矿物", "start_offset": 8, "end_offset": 12, "text": "碱性长石"},
#       {"id": 2, "label": "属性数值(比例)等", "start_offset": 13, "end_offset": 17, "text": "32%"},
#       {"id": 3, "label": "矿物", "start_offset": 18, "end_offset": 21, "text": "斜长石"},
#       {"id": 4, "label": "属性数值(比例)等", "start_offset": 22, "end_offset": 26, "text": "30%"},
#       {"id": 5, "label": "矿物", "start_offset": 27, "end_offset": 29, "text": "石英"},
#       {"id": 6, "label": "属性数值(比例)等", "start_offset": 30, "end_offset": 34, "text": "25%"},
#       {"id": 7, "label": "矿物", "start_offset": 35, "end_offset": 38, "text": "黑云母"},
#       {"id": 8, "label": "属性数值(比例)等", "start_offset": 39, "end_offset": 42, "text": "8%"},
#       {"id": 9, "label": "矿物类型", "start_offset": 44, "end_offset": 47, "text": "副矿物"},
#       {"id": 10, "label": "属性数值(比例)等", "start_offset": 48, "end_offset": 51, "text": "5%"},
#       {"id": 11, "label": "矿物", "start_offset": 54, "end_offset": 57, "text": "磁铁矿"},
#       {"id": 12, "label": "矿物", "start_offset": 58, "end_offset": 61, "text": "钛铁矿"},
#       {"id": 13, "label": "矿物", "start_offset": 62, "end_offset": 64, "text": "榍石"},
#       {"id": 14, "label": "矿物", "start_offset": 65, "end_offset": 68, "text": "褐帘石"},
#       {"id": 15, "label": "矿物", "start_offset": 69, "end_offset": 71, "text": "锆石"},
#       {"id": 16, "label": "矿物", "start_offset": 72, "end_offset": 75, "text": "独居石"}}
# Failed to correct JSON object: {"id": 1, "text": "斑晶包括钾长石、斜长石、石英。",
# "entities": [
#       {"id": 1, "label": "矿物", "start_offset": 4, "end_offset": 7, "text": "钾长石"},
#       {"id": 2, "label": "矿物", "start_offset": 8, "end_offset": 11, "text": "斜长石"},
#       {"id": 3, "label": "矿物", "start_offset": 12, "end_offset": 14, "text": "石英"}}
# Failed to correct JSON object: {"id": 1, "text": "钾长石呈灰白-浅黄色，自形-半自形，为长板状巨晶，粒径为1.5～2.5cm，个别长度可达3cm，巨晶占斑晶15%～20%。",
# "entities": [
#       {"id": 1, "label": "矿物", "start_offset": 0, "end_offset": 3, "text": "钾长石"},
#       {"id": 2, "label": "颜色", "start_offset": 4, "end_offset": 11, "text": "灰白-浅黄色"},
#       {"id": 3, "label": "矿物形态", "start_offset": 12, "end_offset": 16, "text": "自形-半自形"},
#       {"id": 4, "label": "矿物形态", "start_offset": 18, "end_offset": 23, "text": "长板状"},
#       {"id": 5, "label": "属性：数值(比例)等", "start_offset": 30, "end_offset": 39, "text": "1.5～2.5cm"},
#       {"id": 6, "label": "属性：数值(比例)等", "start_offset": 45, "end_offset": 47, "text": "3cm"},
#       {"id": 7, "label": "属性：数值(比例)等", "start_offset": 52, "end_offset": 56, "text": "巨晶"},
#       {"id": 8, "label": "属性：数值(比例)等", "start_offset": 57, "end_offset": 60, "text": "斑晶"},
#       {"id": 9, "label": "属性：数值(比例)等", "start_offset": 61, "end_offset": 67, "text": "15%～20%"}}
# Failed to correct JSON object: {"id": 1, "text": "基质由斜长石、钾长石、石英、黑云母组成(图4-2)。",
# "entities": [
#       {"id": 1, "label": "矿物", "start_offset": 3, "end_offset": 6, "text": "斜长石"},
#       {"id": 2, "label": "矿物", "start_offset": 7, "end_offset": 10, "text": "钾长石"},
#       {"id": 3, "label": "矿物", "start_offset": 11, "end_offset": 13, "text": "石英"},
#       {"id": 4, "label": "矿物", "start_offset": 14, "end_offset": 17, "text": "黑云母"},
#       {"id": 5, "label": "图表", "start_offset": 20, "end_offset": 26, "text": "图4-2"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "在个旧东区，等粒花岗岩大部分隐伏于地下，仅零星出露于个旧矿区，以及东区的白沙冲、老厂南部、新山等地。",
#   "entities": [
#     {"id": 1, "label": "区域，矿集区", "start_offset": 1, "end_offset": 5, "text": "个旧东区"},
#     {"id": 2, "label": "岩石", "start_offset": 6, "end_offset": 12, "text": "等粒花岗岩"},
#     {"id": 3, "label": "矿区", "start_offset": 28, "end_offset": 32, "text": "个旧矿区"},
#     {"id": 4, "label": "矿区位置", "start_offset": 35, "end_offset": 37, "text": "东区"},
#     {"id": 5, "label": "地理位置、方位、方向等", "start_offset": 38, "end_offset": 41, "text": "白沙冲"},
#     {"id": 6, "label": "地理位置、方位、方向等", "start_offset": 42, "end_offset": 46, "text": "老厂南部"},
#     {"id": 7, "label": "地理位置、方位、方向等", "start_offset": 47, "end_offset": 49, "text": "新山"}}
# Failed to correct JSON object: {"id": 1, "text": "在老厂矿田，斑状花岗岩与等粒花岗岩之间具有明显的接触界线，缺少可识别的冷凝边。",
# "entities": [
#       {"id": 1, "label": "矿区", "start_offset": 1, "end_offset": 5, "text": "老厂矿田"},
#       {"id": 2, "label": "岩石", "start_offset": 6, "end_offset": 12, "text": "斑状花岗岩"},
#       {"id": 3, "label": "岩石", "start_offset": 13, "end_offset": 19, "text": "等粒花岗岩"},
#       {"id": 4, "label": "构造部位", "start_offset": 22, "end_offset": 26, "text": "接触界线"},
#       {"id": 5, "label": "岩石结构", "start_offset": 35, "end_offset": 38, "text": "冷凝边"}}
# Failed to correct JSON object: {"id": 1, "text": "这些花岗岩均侵入个旧组碳酸盐岩中。",
# "entities": [
#       {"id": 1, "label": "岩石", "start_offset": 2, "end_offset": 5, "text": "花岗岩"},
#       {"id": 2, "label": "年代地层", "start_offset": 10, "end_offset": 13, "text": "个旧组"},
#       {"id": 3, "label": "岩石", "start_offset": 14, "end_offset": 19, "text": "碳酸盐岩"}}
# Failed to correct JSON object: {"id": 1, "text": "等粒花岗岩(老厂矿区)的主要造岩矿物为碱性长石(35%)、斜长石(27%)、石英(28%)和黑云母(5%),副矿物约占 5%,其中包括锆石、磷灰石、榍石、钛铁矿、磁铁矿、褐帘石、独居石、电气石、萤石。",
# "entities": [
#       {"id": 1, "label": "岩石", "start_offset": 0, "end_offset": 6, "text": "等粒花岗岩"},
#       {"id": 2, "label": "矿区", "start_offset": 7, "end_offset": 13, "text": "老厂矿区"},
#       {"id": 3, "label": "矿物", "start_offset": 22, "end_offset": 26, "text": "碱性长石"},
#       {"id": 4, "label": "品位", "start_offset": 27, "end_offset": 31, "text": "35%"},
#       {"id": 5, "label": "矿物", "start_offset": 32, "end_offset": 35, "text": "斜长石"},
#       {"id": 6, "label": "品位", "start_offset": 36, "end_offset": 40, "text": "27%"},
#       {"id": 7, "label": "矿物", "start_offset": 41, "end_offset": 43, "text": "石英"},
#       {"id": 8, "label": "品位", "start_offset": 44, "end_offset": 48, "text": "28%"},
#       {"id": 9, "label": "矿物", "start_offset": 49, "end_offset": 52, "text": "黑云母"},
#       {"id": 10, "label": "品位", "start_offset": 53, "end_offset": 56, "text": "5%"},
#       {"id": 11, "label": "矿物类型", "start_offset": 57, "end_offset": 60, "text": "副矿物"},
#       {"id": 12, "label": "品位", "start_offset": 63, "end_offset": 65, "text": "5%"},
#       {"id": 13, "label": "矿物", "start_offset": 68, "end_offset": 70, "text": "锆石"},
#       {"id": 14, "label": "矿物", "start_offset": 71, "end_offset": 74, "text": "磷灰石"},
#       {"id": 15, "label": "矿物", "start_offset": 75, "end_offset": 77, "text": "榍石"},
#       {"id": 16, "label": "矿物", "start_offset": 78, "end_offset": 82, "text": "钛铁矿"},
#       {"id": 17, "label": "矿物", "start_offset": 83, "end_offset": 86, "text": "磁铁矿"},
#       {"id": 18, "label": "矿物", "start_offset": 87, "end_offset": 90, "text": "褐帘石"},
#       {"id": 19, "label": "矿物", "start_offset": 91, "end_offset": 94, "text": "独居石"},
#       {"id": 20, "label": "矿物", "start_offset": 95, "end_offset": 98, "text": "电气石"},
#       {"id": 21, "label": "矿物", "start_offset": 99, "end_offset": 101, "text": "萤石"}}
# Failed to correct JSON object: {"id": 1, "text": "与斑状花岗岩相比，萤石、电气石、黄玉和白云母在等粒花岗岩中的含量有所增加(图4-3)。",
# "entities": [
#       {"id": 1, "label": "岩石", "start_offset": 1, "end_offset": 6, "text": "斑状花岗岩"},
#       {"id": 2, "label": "矿物", "start_offset": 9, "end_offset": 11, "text": "萤石"},
#       {"id": 3, "label": "矿物", "start_offset": 12, "end_offset": 16, "text": "电气石"},
#       {"id": 4, "label": "矿物", "start_offset": 17, "end_offset": 19, "text": "黄玉"},
#       {"id": 5, "label": "矿物", "start_offset": 20, "end_offset": 23, "text": "白云母"},
#       {"id": 6, "label": "岩石", "start_offset": 25, "end_offset": 30, "text": "等粒花岗岩"},
#       {"id": 7, "label": "图表", "start_offset": 38, "end_offset": 44, "text": "图4-3"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "斑状石英二长岩是贾沙岩体的主要岩石类型之一。",
#   "entities": [
#     {"id": 1, "label": "岩石", "start_offset": 0, "end_offset": 7, "text": "斑状石英二长岩"},
#     {"id": 2, "label": "岩体", "start_offset": 8, "end_offset": 12, "text": "贾沙岩体"},
#     {"id": 3, "label": "岩石类型", "start_offset": 13, "end_offset": 18, "text": "主要岩石类型"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "岩石呈灰色，具斑状中粗粒结构。",
#   "entities": [
#     {"id": 1, "label": "颜色", "start_offset": 3, "end_offset": 5, "text": "灰色"},
#     {"id": 2, "label": "岩石结构", "start_offset": 8, "end_offset": 16, "text": "斑状中粗粒结构"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "主要矿物有斜长石(35%)、钾长石(35%)、石英(15%)、角闪石(10%);副矿物约占5%,包括磷灰石、磁铁矿、楣石、锆石等。",
#   "entities": [
#     {"id": 1, "label": "矿物类型", "start_offset": 0, "end_offset": 4, "text": "主要矿物"},
#     {"id": 2, "label": "矿物", "start_offset": 5, "end_offset": 8, "text": "斜长石"},
#     {"id": 3, "label": "属性数值(比例)等", "start_offset": 9, "end_offset": 13, "text": "35%"},
#     {"id": 4, "label": "矿物", "start_offset": 15, "end_offset": 18, "text": "钾长石"},
#     {"id": 5, "label": "属性数值(比例)等", "start_offset": 19, "end_offset": 23, "text": "35%"},
#     {"id": 6, "label": "矿物", "start_offset": 25, "end_offset": 27, "text": "石英"},
#     {"id": 7, "label": "属性数值(比例)等", "start_offset": 28, "end_offset": 32, "text": "15%"},
#     {"id": 8, "label": "矿物", "start_offset": 34, "end_offset": 37, "text": "角闪石"},
#     {"id": 9, "label": "属性数值(比例)等", "start_offset": 38, "end_offset": 42, "text": "10%"},
# ...
#     {"id": 4, "label": "数据统计术语", "start_offset": 24, "end_offset": 26, "text": "公式"},
#     {"id": 5, "label": "数据统计术语", "start_offset": 38, "end_offset": 46, "text": "饱和流体"},
#     {"id": 6, "label": "数据统计术语", "start_offset": 47, "end_offset": 51, "text": "压力"},
#     {"id": 7, "label": "数据统计术语", "start_offset": 52, "end_offset": 54, "text": "公式"},
#     {"id": 8, "label": "数据统计术语", "start_offset": 55, "end_offset": 57, "text": "计算"},
#     {"id": 9, "label": "数据统计术语", "start_offset": 58, "end_offset": 62, "text": "流体"},
#     {"id": 10, "label": "数据统计术语", "start_offset": 63, "end_offset": 65, "text": "深度"},
#     {"id": 11, "label": "数据统计术语", "start_offset": 66, "end_offset": 68, "text": "换算"},
#     {"id": 12, "label": "数据统计术语", "start_offset": 69, "end_offset": 71, "text": "参考"},
#     {"id": 13, "label": "数据统计术语", "start_offset": 72, "end_offset": 74, "text": "前人"},
#     {"id": 14, "label": "数据统计术语", "start_offset": 75, "end_offset": 79, "text": "相关"},
#     {"id": 15, "label": "数据统计术语", "start_offset": 80, "end_offset": 82, "text": "研究"},
#     {"id": 16, "label": "数据统计术语", "start_offset": 83, "end_offset": 85, "text": "成果"},
#     {"id": 17, "label": "数据统计术语", "start_offset": 86, "end_offset": 88, "text": "最终"},
#     {"id": 18, "label": "数据统计术语", "start_offset": 89, "end_offset": 91, "text": "采用"},
#     {"id": 19, "label": "数据统计术语", "start_offset": 92, "end_offset": 94, "text": "孙丰月"},
#     {"id": 20, "label": "数据统计术语", "start_offset": 95, "end_offset": 97, "text": "等"},
#     {"id": 21, "label": "数据统计术语", "start_offset": 98, "end_offset": 100, "text": "公式"},
#     {"id": 22, "label": "数据统计术语", "start_offset": 101, "end_offset": 103, "text": "计算"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "5.5 流体包裹体特征",
#   "entities": [
#     {
#       "id": 1,
#       "label": "副标题",
#       "start_offset": 0,
#       "end_offset": 3,
#       "text": "5.5"
#     },
#     {
#       "id": 2,
#       "label": "岩石/矿物微观特征",
#       "start_offset": 4,
#       "end_offset": 12,
#       "text": "流体包裹体"
#     },
#     {
#       "id": 3,
#       "label": "特点",
#       "start_offset": 12,
#       "end_offset": 14,
#       "text": "特征"
#     }}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "5.5.1 流体包裹体岩相学特征及分类",
#   "entities": [
#     {
#       "id": 1,
#       "label": "副标题",
#       "start_offset": 0,
#       "end_offset": 5,
#       "text": "5.5.1"
#     },
#     {
#       "id": 2,
#       "label": "岩石/矿物微观特征",
#       "start_offset": 6,
#       "end_offset": 14,
#       "text": "流体包裹体"
#     },
#     {
#       "id": 3,
#       "label": "岩石结构",
#       "start_offset": 14,
#       "end_offset": 20,
#       "text": "岩相学"
#     }}
# Failed to correct JSON object: {"id": 1, "text": "个旧各矿床的流体包裹体类型丰富而复杂，不同矿田(体)观测到的包裹体特征有所不同。",
# "entities": [
#       {"id": 1, "label": "矿床", "start_offset": 2, "end_offset": 5, "text": "矿床"},
#       {"id": 2, "label": "岩石/矿物微观特征", "start_offset": 7, "end_offset": 13, "text": "流体包裹体"},
#       {"id": 3, "label": "矿区", "start_offset": 24, "end_offset": 26, "text": "矿田"},
#       {"id": 4, "label": "岩石/矿物微观特征", "start_offset": 32, "end_offset": 36, "text": "包裹体"},
#       {"id": 5, "label": "特点", "start_offset": 14, "end_offset": 23, "text": "类型丰富而复杂"},
#       {"id": 6, "label": "特点", "start_offset": 37, "end_offset": 49, "text": "包裹体特征有所不同"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "总体来说，本次研究对象主要为赋存在方解石、萤石、石英和石榴子石中的流体包裹体，另对主矿物为透闪石、透辉石、符山石的少量流体包裹体也做了测试。",
#   "entities": [
#     {"id": 1, "label": "矿物", "start_offset": 20, "end_offset": 23, "text": "方解石"},
#     {"id": 2, "label": "矿物", "start_offset": 24, "end_offset": 26, "text": "萤石"},
#     {"id": 3, "label": "矿物", "start_offset": 27, "end_offset": 29, "text": "石英"},
#     {"id": 4, "label": "矿物", "start_offset": 30, "end_offset": 34, "text": "石榴子石"},
#     {"id": 5, "label": "岩石/矿物微观特征", "start_offset": 36, "end_offset": 42, "text": "流体包裹体"},
#     {"id": 6, "label": "矿物", "start_offset": 50, "end_offset": 53, "text": "透闪石"},
#     {"id": 7, "label": "矿物", "start_offset": 54, "end_offset": 57, "text": "透辉石"},
#     {"id": 8, "label": "矿物", "start_offset": 58, "end_offset": 61, "text": "符山石"},
#     {"id": 9, "label": "岩石/矿物微观特征", "start_offset": 64, "end_offset": 70, "text": "流体包裹体"}}
# Failed to correct JSON object: {"id": 1, "text": "所研究的包裹体绝大多数为原生包裹体，另有少量假次生和次生包裹体。",
# "entities": [
#       {"id": 1, "label": "岩石/矿物微观特征", "start_offset": 5, "end_offset": 8, "text": "包裹体"},
#       {"id": 2, "label": "岩石/矿物微观特征", "start_offset": 14, "end_offset": 18, "text": "原生包裹体"},
#       {"id": 3, "label": "岩石/矿物微观特征", "start_offset": 23, "end_offset": 27, "text": "假次生包裹体"},
#       {"id": 4, "label": "岩石/矿物微观特征", "start_offset": 30, "end_offset": 34, "text": "次生包裹体"}}
# Failed to correct JSON object: {"id": 1, "text": "按照气液充填程度、是否含子晶、是否含液态CO2总体可分为四大类，按照均一方式的不同又可分为8个亚类(图5-8):",
# "entities": [
#       {"id": 1, "label": "图表", "start_offset": 52, "end_offset": 58, "text": "图5-8"}}
# Failed to correct JSON object: {"id": 1, "text": "纯相态包裹体(P型): 该类包裹体在个旧各矿床均有发育，又可分为纯气相(PV型)、纯液相(PL型)和纯CO2相(PC型)。",
# "entities": [
#       {"id": 1, "label": "岩石/矿物微观特征", "start_offset": 0, "end_offset": 10, "text": "纯相态包裹体(P型)"},
#       {"id": 2, "label": "岩石/矿物微观特征", "start_offset": 35, "end_offset": 41, "text": "纯气相(PV型)"},
#       {"id": 3, "label": "岩石/矿物微观特征", "start_offset": 44, "end_offset": 50, "text": "纯液相(PL型)"},
#       {"id": 4, "label": "岩石/矿物微观特征", "start_offset": 53, "end_offset": 61, "text": "纯CO2相(PC型)"},
#       {"id": 5, "label": "矿床", "start_offset": 18, "end_offset": 20, "text": "矿床"}}
# Failed to correct JSON object: {"id": 1, "text": "纯气相(PV型)为单一气相包裹体，形态多为椭圆形，大小5～20μm，气/液比大于90%,主要孤立分布，少数成群分布。",
# "entities": [
#       {"id": 1, "label": "岩石/矿物微观结构特征", "start_offset": 0, "end_offset": 10, "text": "纯气相(PV型)"},
#       {"id": 2, "label": "岩石/矿物微观结构特征", "start_offset": 12, "end_offset": 18, "text": "单一气相包裹体"},
#       {"id": 3, "label": "矿物形态", "start_offset": 23, "end_offset": 27, "text": "椭圆形"},
#       {"id": 4, "label": "属性数值(比例)等", "start_offset": 30, "end_offset": 36, "text": "5～20μm"},
#       {"id": 5, "label": "地物化条件/特征", "start_offset": 38, "end_offset": 42, "text": "气/液比"},
#       {"id": 6, "label": "属性数值(比例)等", "start_offset": 43, "end_offset": 47, "text": "大于90%"},
#       {"id": 7, "label": "矿体分布", "start_offset": 49, "end_offset": 55, "text": "孤立分布"},
#       {"id": 8, "label": "矿体分布", "start_offset": 58, "end_offset": 64, "text": "成群分布"}}
# Failed to correct JSON object: {"id": 1, "text": "纯液相(PL型)多呈椭圆状和不规则形，大小3~15μm，气/液比多小于5%。",
# "entities": [
#       {"id": 1, "label": "岩石/矿物微观结构特征", "start_offset": 0, "end_offset": 8, "text": "纯液相(PL型)"},
#       {"id": 2, "label": "矿物形态", "start_offset": 9, "end_offset": 12, "text": "椭圆状"},
#       {"id": 3, "label": "矿物形态", "start_offset": 13, "end_offset": 18, "text": "不规则形"},
#       {"id": 4, "label": "属性：数值(比例)等", "start_offset": 20, "end_offset": 26, "text": "3~15μm"},
#       {"id": 5, "label": "地物化条件/特征", "start_offset": 28, "end_offset": 32, "text": "气/液比"},
#       {"id": 6, "label": "属性：数值(比例)等", "start_offset": 35, "end_offset": 38, "text": "5%"}}
# Failed to correct JSON object: {"id": 1, "text": "气液两相包裹体(T型):该类包裹体包括富气相包裹体(VL型)和富液相包裹体(LV型)。",
# "entities": [
#       {"id": 1, "label": "岩石/矿物微观特征", "start_offset": 0, "end_offset": 10, "text": "气液两相包裹体(T型)"},
#       {"id": 2, "label": "岩石/矿物微观特征", "start_offset": 21, "end_offset": 28, "text": "富气相包裹体(VL型)"},
#       {"id": 3, "label": "岩石/矿物微观特征", "start_offset": 31, "end_offset": 38, "text": "富液相包裹体(LV型)"}}
# Failed to correct JSON object: {"id": 1, "text": "富气相包裹体(VL型)，指在室温下含有一较大气泡和少量液相、加热均一至气相的包裹体。",
# "entities": [
#       {"id": 1, "label": "岩石/矿物微观特征", "start_offset": 0, "end_offset": 11, "text": "富气相包裹体(VL型)"},
#       {"id": 2, "label": "特点", "start_offset": 13, "end_offset": 55, "text": "在室温下含有一较大气泡和少量液相、加热均一至气相的包裹体"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "此类包裹体较少，只在部分样品中发育，矽卡岩阶段和硫化物阶段均有发育，大小较大(8～60μm)，气/液比为50%~90%,以70%～80%居多。",
#   "entities": [
#     {"id": 1, "label": "岩石/矿物微观结构特征", "start_offset": 2, "end_offset": 6, "text": "包裹体"},
#     {"id": 2, "label": "趋势、数据分布、程度、顺序", "start_offset": 7, "end_offset": 9, "text": "较少"},
#     {"id": 3, "label": "实验处理（样品）", "start_offset": 14, "end_offset": 18, "text": "样品"},
#     {"id": 4, "label": "成矿阶段、成矿期", "start_offset": 24, "end_offset": 29, "text": "矽卡岩阶段"},
#     {"id": 5, "label": "成矿阶段、成矿期", "start_offset": 30, "end_offset": 36, "text": "硫化物阶段"},
#     {"id": 6, "label": "趋势、数据分布、程度、顺序", "start_offset": 41, "end_offset": 43, "text": "较大"},
#     {"id": 7, "label": "属性：数值(比例)等", "start_offset": 44, "end_offset": 51, "text": "8～60μm"},
#     {"id": 8, "label": "地物化条件/特征", "start_offset": 53, "end_offset": 57, "text": "气/液比"},
#     {"id": 9, "label": "属性：数值(比例)等", "start_offset": 58, "end_offset": 64, "text": "50%~90%"},
#     {"id": 10, "label": "属性：数值(比例)等", "start_offset": 67, "end_offset": 74, "text": "70%～80%"},
#     {"id": 11, "label": "趋势、数据分布、程度、顺序", "start_offset": 75, "end_offset": 77, "text": "居多"}}
# Failed to correct JSON object: {"id": 1, "text": "富液相包裹体(LV型)指室温下主要由液相和一个小气泡组成的二相、加热均一至液相的包裹体，这类包裹体发育最为广泛，在各矿床各阶段均有发育，大小3～86μm，气/液比5%～50%(10%～30%居多)，与富气相共存时，可见气/液比为55%的富液相包裹体。",
# "entities": [
#     {"id": 1, "label": "岩石/矿物微观特征", "start_offset": 0, "end_offset": 11, "text": "富液相包裹体(LV型)"},
#     {"id": 2, "label": "岩石/矿物微观特征", "start_offset": 118, "end_offset": 124, "text": "富液相包裹体"},
#     {"id": 3, "label": "属性数值(比例)等", "start_offset": 70, "end_offset": 76, "text": "3～86μm"},
#     {"id": 4, "label": "属性数值(比例)等", "start_offset": 81, "end_offset": 87, "text": "5%～50%"},
#     {"id": 5, "label": "属性数值(比例)等", "start_offset": 88, "end_offset": 95, "text": "10%～30%"},
#     {"id": 6, "label": "属性数值(比例)等", "start_offset": 114, "end_offset": 117, "text": "55%"},
#     {"id": 7, "label": "特点", "start_offset": 12, "end_offset": 67, "text": "室温下主要由液相和一个小气泡组成的二相、加热均一至液相的包裹体，这类包裹体发育最为广泛，在各矿床各阶段均有发育"},
#     {"id": 8, "label": "地物化/条件", "start_offset": 77, "end_offset": 81, "text": "气/液比"},
#     {"id": 9, "label": "地物化/条件", "start_offset": 109, "end_offset": 113, "text": "气/液比"},
#     {"id": 10, "label": "作用条件", "start_offset": 99, "end_offset": 106, "text": "与富气相共存时"}}
# Failed to correct JSON object: {"id": 1, "text": "含子晶包裹体(S型):由气相、液相和子矿物共同组成的包裹体，按照加热均一方式不同又分为两类。",
# "entities": [
#       {"id": 1, "label": "岩石/矿物微观特征", "start_offset": 0, "end_offset": 9, "text": "含子晶包裹体(S型)"},
#       {"id": 2, "label": "化学参数，术语", "start_offset": 12, "end_offset": 15, "text": "气相"},
#       {"id": 3, "label": "化学参数，术语", "start_offset": 16, "end_offset": 19, "text": "液相"},
#       {"id": 4, "label": "矿物", "start_offset": 20, "end_offset": 23, "text": "子矿物"},
#       {"id": 5, "label": "特点", "start_offset": 24, "end_offset": 33, "text": "共同组成的包裹体"},
#       {"id": 6, "label": "作用方式", "start_offset": 38, "end_offset": 42, "text": "加热均一"}}
# Failed to correct JSON object: {
#   "id": 1,
#   "text": "一类是不饱和含子晶包裹体(US型),这类包裹体在加热过程中，子晶先消失，后气泡消失均一至液相，为不饱和流体形成，大小为4～20μm，气/液比7%～55%；另一类为过饱和含子晶包裹体(OS型)，这类包裹体在加热过程中，气泡先消失，由子晶消失达到最终均一状态，为过饱和流体形成，较前者发育较少，大小为6~12μm, 气/液比10%～25%。",
#   "entities": [
#     {"id": 1, "label": "岩石/矿物微观结构特征", "start_offset": 4, "end_offset": 18, "text": "不饱和含子晶包裹体(US型)"},
#     {"id": 2, "label": "岩石/矿物微观结构特征", "start_offset": 19, "end_offset": 22, "text": "包裹体"},
#     {"id": 3, "label": "作用条件", "start_offset": 23, "end_offset": 29, "text": "加热过程中"},
#     {"id": 4, "label": "地物化条件/特征", "start_offset": 30, "end_offset": 32, "text": "子晶"},
#     {"id": 5, "label": "地物化条件/特征", "start_offset": 35, "end_offset": 37, "text": "气泡"},
#     {"id": 6, "label": "地物化条件/特征", "start_offset": 44, "end_offset": 46, "text": "液相"},
#     {"id": 7, "label": "地物化条件/特征", "start_offset": 48, "end_offset": 54, "text": "不饱和流体"},
#     {"id": 8, "label": "属性：数值(比例)等", "start_offset": 57, "end_offset": 63, "text": "4～20μm"},
#     {"id": 9, "label": "属性：数值(比例)等", "start_offset": 66, "end_offset": 72, "text": "7%～55%"},
#     {"id": 10, "label": "岩石/矿物微观结构特征", "start_offset": 75, "end_offset": 90, "text": "过饱和含子晶包裹体(OS型)"},
#     {"id": 11, "label": "岩石/矿物微观结构特征", "start_offset": 91, "end_offset": 94, "text": "包裹体"},
#     {"id": 12, "label": "作用条件", "start_offset": 95, "end_offset": 101, "text": "加热过程中"},
#     {"id": 13, "label": "地物化条件/特征", "start_offset": 102, "end_offset": 104, "text": "气泡"},
#     {"id": 14, "label": "地物化条件/特征", "start_offset": 111, "end_offset": 113, "text": "子晶"},
#     {"id": 15, "label": "地物化条件/特征", "start_offset": 120, "end_offset": 122, "text": "均一"},
#     {"id": 16, "label": "地物化条件/特征", "start_offset": 124, "end_offset": 130, "text": "过饱和流体"},
#     {"id": 17, "label": "趋势、数据分布、程度、顺序", "start_offset": 133, "end_offset": 135, "text": "较少"},
#     {"id": 18, "label": "属性：数值(比例)等", "start_offset": 138, "end_offset": 144, "text": "6~12μm"},
#     {"id": 19, "label": "属性：数值(比例)等", "start_offset": 147, "end_offset": 153, "text": "10%～25%"}}
# Failed to correct JSON object: {"id": 1, "text": "含液态CO2包裹体(C型):由气相CO₂、液相CO2和盐水溶液组成。",
# "entities": [
#       {"id": 1, "label": "岩石/矿物微观结构特征", "start_offset": 0, "end_offset": 12, "text": "含液态CO2包裹体(C型)"},
#       {"id": 2, "label": "化学组分", "start_offset": 15, "end_offset": 18, "text": "气相CO₂"},
#       {"id": 3, "label": "化学组分", "start_offset": 19, "end_offset": 22, "text": "液相CO2"},
#       {"id": 4, "label": "化学组分", "start_offset": 23, "end_offset": 27, "text": "盐水溶液"}}
# Failed to correct JSON object: {"id": 1, "text": "加热过程中气相CO2和液相CO2先均一至液相，再和盐水溶液均一至液相。",
# "entities": [
#       {"id": 1, "label": "作用条件", "start_offset": 0, "end_offset": 6, "text": "加热过程中"},
#       {"id": 2, "label": "化学组分", "start_offset": 7, "end_offset": 13, "text": "气相CO2"},
#       {"id": 3, "label": "化学组分", "start_offset": 14, "end_offset": 20, "text": "液相CO2"},
#       {"id": 4, "label": "地物化条件/特征", "start_offset": 21, "end_offset": 24, "text": "均一"},
#       {"id": 5, "label": "地物化条件/特征", "start_offset": 31, "end_offset": 34, "text": "液相"},
#       {"id": 6, "label": "化学组分", "start_offset": 36, "end_offset": 42, "text": "盐水溶液"},
#       {"id": 7, "label": "地物化条件/特征", "start_offset": 43, "end_offset": 46, "text": "均一"},
#       {"id": 8, "label": "地物化条件/特征", "start_offset": 53, "end_offset": 56, "text": "液相"}}
# Failed to correct JSON object: {"id": 1, "text": "总之，成矿主阶段 (I-Ⅲ阶段)发育的包裹体类型多样，均含有沸腾包裹体。",
# "entities": [
#       {"id": 1, "label": "成矿阶段、成矿期", "start_offset": 3, "end_offset": 12, "text": "成矿主阶段 (I-Ⅲ阶段)"},
#       {"id": 2, "label": "岩石/矿物微观特征", "start_offset": 18, "end_offset": 22, "text": "包裹体"},
#       {"id": 3, "label": "岩石/矿物微观特征", "start_offset": 34, "end_offset": 38, "text": "包裹体"},
#       {"id": 4, "label": "岩石/矿物微观特征", "start_offset": 43, "end_offset": 47, "text": "沸腾包裹体"}}
# Failed to correct JSON object: {"id": 25, "text": "矽卡岩阶段和氧化物阶段包裹体发育较小且较少，但含子晶包裹体 (S型包裹体)较多；硫化物阶段流体句裹体最为发育，数量多且较大，该阶段还发育C型包裹体。",
# "entities": [
#       {"id": 1, "label": "成矿阶段、成矿期", "start_offset": 0, "end_offset": 5, "text": "矽卡岩阶段"},
#       {"id": 2, "label": "成矿阶段、成矿期", "start_offset": 6, "end_offset": 14, "text": "氧化物阶段"},
#       {"id": 3, "label": "岩石/矿物微观特征", "start_offset": 31, "end_offset": 36, "text": "S型包裹体"},
#       {"id": 4, "label": "成矿阶段、成矿期", "start_offset": 40, "end_offset": 45, "text": "硫化物阶段"},
#       {"id": 5, "label": "岩石/矿物微观特征", "start_offset": 46, "end_offset": 51, "text": "流体包裹体"},
#       {"id": 6, "label": "特点", "start_offset": 52, "end_offset": 67, "text": "最为发育，数量多且较大"},
#       {"id": 7, "label": "岩石/矿物微观特征", "start_offset": 68, "end_offset": 73, "text": "C型包裹体"}}
# Failed to correct JSON object: {"id": 1, "text": "说明本阶段CO₂ 成分开始增多：碳酸盐阶段流体包裹体较不发育，仅见少量较小的富液相流体包裹体，气/液比较小。",
# "entities": [
#       {"id": 1, "label": "化学组分", "start_offset": 6, "end_offset": 9, "text": "CO₂"},
#       {"id": 2, "label": "成矿阶段、成矿期", "start_offset": 18, "end_offset": 24, "text": "碳酸盐阶段"},
#       {"id": 3, "label": "岩石/矿物微观特征", "start_offset": 24, "end_offset": 30, "text": "流体包裹体"},
#       {"id": 4, "label": "岩石/矿物微观特征", "start_offset": 41, "end_offset": 47, "text": "富液相流体包裹体"},
#       {"id": 5, "label": "地物化条件/特征", "start_offset": 48, "end_offset": 52, "text": "气/液比"},
#       {"id": 6, "label": "趋势、数据分布、程度、顺序", "start_offset": 53, "end_offset": 55, "text": "较小"}}
# Extracted 2 JSON objects to extracted_NER.json

# %%
import json


def is_valid_data(data):
    if "entities" not in data :
        return False
    for entity in data["entities"]:
        if "id" not in entity or "label" not in entity or "start_offset" not in entity or "end_offset" not in entity:
            return False
    return True


def process_line(line):
    line = line.replace("```json", "").replace("```", "").strip()
    return line


def extract_data(input_path, output_path, error_log_path):
    valid_data_count = 0
    line_count = 0
    buffer = ""
    inside_object = False
    errors = []

    with open(input_path, 'r', encoding='utf-8') as infile, open(output_path, 'w', encoding='utf-8') as outfile, open(
            error_log_path, 'w', encoding='utf-8') as error_log:
        for line in infile:
            line_count += 1
            line = process_line(line)

            if not line:
                continue  # 跳过空行

            if line.startswith("{") and not inside_object:
                inside_object = True
                buffer += line
            elif line.startswith("}") and inside_object:
                buffer += line
                inside_object = False
                try:
                    data = json.loads(buffer)
                    if isinstance(data, dict) and is_valid_data(data):
                        outfile.write(json.dumps(data, ensure_ascii=False) + '\n')
                        valid_data_count += 1
                except json.JSONDecodeError as e:
                    errors.append(buffer)
                    error_log.write(f"Line {line_count}: {buffer}\n")
                buffer = ""
            elif inside_object:
                buffer += line
            else:
                try:
                    data = json.loads(line)
                    if isinstance(data, dict) and is_valid_data(data):
                        outfile.write(json.dumps(data, ensure_ascii=False) + '\n')
                        valid_data_count += 1
                except json.JSONDecodeError as e:
                    errors.append(line)
                    error_log.write(f"Line {line_count}: {line}\n")

    print(f"Total valid data count: {valid_data_count}")
    print(f"Total errors: {len(errors)}")
    return valid_data_count

# 定义文件路径
input_path = 'NER.txt'
output_path = 'output_ner.json'
error_log_path = 'log_NER.txt'


# 运行提取数据的函数
valid_data_count = extract_data(input_path, output_path, error_log_path)
print(f"Total valid data count: {valid_data_count}")
# Out:
# Total valid data count: 159
# Total errors: 610
# Total valid data count: 159

# %%
import json

def is_valid_data(data):
    if "entities" not in data or "text" not in data:
        return False
    for entity in data["entities"]:
        if "id" not in entity or "label" not in entity or "start_offset" not in entity or "end_offset" not in entity or "text" not in entity:
            return False
    return True

def extract_data(input_path, output_path, error_log_path):
    valid_data_count = 0
    line_count = 0
    buffer = ""
    inside_json_block = False
    errors = []

    with open(input_path, 'r', encoding='utf-8') as infile, open(output_path, 'w', encoding='utf-8') as outfile, open(
            error_log_path, 'w', encoding='utf-8') as error_log:
        for line in infile:
            line_count += 1
            line = line.strip()

            # 检查是否进入或退出```json```标记
            if line.startswith("```json"):
                inside_json_block = True
                buffer = ""
                continue
            elif line.startswith("```") and inside_json_block:
                inside_json_block = False
                # 处理多个JSON对象
                objects = buffer.split('}{')
                for i in range(len(objects)):
                    if i > 0:
                        objects[i] = '{' + objects[i]
                    if i < len(objects) - 1:
                        objects[i] = objects[i] + '}'
                    try:
                        data = json.loads(objects[i])
                        if is_valid_data(data):
                            outfile.write(json.dumps(data, ensure_ascii=False) + '\n')
                            valid_data_count += 1
                        else:
                            error_log.write(f"Invalid data at line {line_count}: {objects[i]}\n")
                    except json.JSONDecodeError as e:
                        error_log.write(f"JSON decode error at line {line_count}: {objects[i]}\n")
                buffer = ""
                continue

            if inside_json_block:
                buffer += line

    print(f"Total valid data count: {valid_data_count}")
    print(f"Total errors: {line_count - valid_data_count}")
    return valid_data_count

# 定义文件路径
input_path = 'NER.txt'
output_path = 'output_ner.json'
error_log_path = 'log_NER.txt'

# 运行提取数据的函数
valid_data_count = extract_data(input_path, output_path, error_log_path)
print(f"Total valid data count: {valid_data_count}")
# Out:
# Total valid data count: 467
# Total errors: 17396
# Total valid data count: 467

# %%
import json
import re

def is_valid_data(data):
    if "entities" not in data or "text" not in data:
        return False
    for entity in data["entities"]:
        if "id" not in entity or "label" not in entity or "start_offset" not in entity or "end_offset" not in entity or "text" not in entity:
            return False
    return True

def clean_json_string(json_string):
    # 去除 JSON 对象内部的多余逗号
    json_string = re.sub(r',\s*}', '}', json_string)
    json_string = re.sub(r',\s*]', ']', json_string)
    return json_string

def extract_data(input_path, output_path, error_log_path):
    valid_data_count = 0
    line_count = 0
    buffer = ""
    errors = []

    with open(input_path, 'r', encoding='utf-8') as infile, open(output_path, 'w', encoding='utf-8') as outfile, open(
            error_log_path, 'w', encoding='utf-8') as error_log:
        for line in infile:
            line_count += 1
            line = line.strip()
            if line:
                buffer += line

        # 将多个 JSON 对象分割开
        json_objects = buffer.replace('}{', '}\n{').split('\n')

        for json_str in json_objects:
            json_str = clean_json_string(json_str)
            try:
                data = json.loads(json_str)
                if is_valid_data(data):
                    outfile.write(json.dumps(data, ensure_ascii=False) + '\n')
                    valid_data_count += 1
                else:
                    error_log.write(f"Invalid data at line {line_count}: {json_str}\n")
            except json.JSONDecodeError as e:
                error_log.write(f"JSON decode error at line {line_count}: {json_str}\n")

    print(f"Total valid data count: {valid_data_count}")
    print(f"Total errors: {line_count - valid_data_count}")
    return valid_data_count

# 定义文件路径
input_path = 'NER.jsonl'
output_path = 'output_ner.json'
error_log_path = 'log_NER.txt'

# 运行提取数据的函数
valid_data_count = extract_data(input_path, output_path, error_log_path)
print(f"Total valid data count: {valid_data_count}")
# Out:
# Total valid data count: 1233
# Total errors: 15404
# Total valid data count: 1233

# %%
import json

def merge_relations_with_entities(user_input, response):
    user_data = json.loads(user_input)

    # 尝试解析 response 为 JSON 对象或 JSON 数组
    try:
        relations_data = json.loads(response)
        if isinstance(relations_data, dict) and 'relations' in relations_data:
            user_data['relations'] = relations_data['relations']
        elif isinstance(relations_data, list):
            user_data['relations'] = relations_data
        else:
            user_data['relations'] = []
    except json.JSONDecodeError:
        user_data['relations'] = []

    return user_data

def process_data(input_path, output_path, error_log_path):
    line_count = 0
    valid_data_count = 0
    errors = []

    with open(input_path, 'r', encoding='utf-8') as infile, open(output_path, 'w', encoding='utf-8') as outfile, open(
            error_log_path, 'w', encoding='utf-8') as error_log:
        lines = infile.readlines()
        user_input = ""
        response = ""
        processing_user_input = False

        for line in lines:
            line_count += 1
            line = line.strip()

            if line.startswith("User Input:"):
                processing_user_input = True
                user_input = line.replace("User Input: ", "")
            elif line.startswith("Response:"):
                processing_user_input = False
                response = line.replace("Response: ", "")

                # 先移除 ```json 和 ``` 标签
                if response.startswith("```json"):
                    response = response[7:].strip()  # Remove starting ```json
                if response.endswith("```"):
                    response = response[:-3].strip()  # Remove ending ```

                try:
                    merged_data = merge_relations_with_entities(user_input, response)
                    outfile.write(json.dumps(merged_data, ensure_ascii=False) + '\n')
                    valid_data_count += 1
                except Exception as e:
                    error_log.write(f"Error processing data at line {line_count}: {str(e)}\n")
                user_input = ""
                response = ""

    return valid_data_count

# 定义文件路径
input_path = 'RE.txt'
output_path = 'output_RE.jsonl'
error_log_path = 'log_RE.txt'

# 运行处理数据的函数
valid_data_count = process_data(input_path, output_path, error_log_path)
valid_data_count
# Out:
# 994

# %%
import json
import re

def extract_relations(response):
    # 使用正则表达式提取 "relations" 部分
    match = re.search(r'"relations":\s*(\[[^\]]*\])', response, re.DOTALL)
    if match:
        return match.group(1)
    return "[]"

def merge_relations_with_entities(user_input, response):
    user_data = json.loads(user_input)

    try:
        relations_str = extract_relations(response)
        relations_data = json.loads(relations_str)
        user_data['relations'] = relations_data
    except json.JSONDecodeError as e:
        print(f"JSONDecodeError: {str(e)} with response: {response}")
        user_data['relations'] = []
    except Exception as e:
        print(f"Error merging data: {str(e)}")
        user_data['relations'] = []

    return user_data

def process_data(input_path, output_path, error_log_path):
    line_count = 0
    valid_data_count = 0

    with open(input_path, 'r', encoding='utf-8') as infile, open(output_path, 'w', encoding='utf-8') as outfile, open(error_log_path, 'w', encoding='utf-8') as error_log:
        lines = infile.readlines()
        user_input = ""
        response = ""
        processing_user_input = False

        for line in lines:
            line_count += 1
            line = line.strip()

            if line.startswith("User Input:"):
                if user_input and response:
                    try:
                        merged_data = merge_relations_with_entities(user_input, response)
                        outfile.write(json.dumps(merged_data, ensure_ascii=False) + '\n')
                        valid_data_count += 1
                    except Exception as e:
                        error_log.write(f"Error processing data at line {line_count}: {str(e)}\n")
                user_input = line.replace("User Input: ", "")
                response = ""
                processing_user_input = True
                error_log.write(f"Read User Input: {user_input}\n")  # Debug log
            elif line.startswith("Response:"):
                processing_user_input = False
                response = line.replace("Response: ", "")
                error_log.write(f"Read Response: {response}\n")  # Debug log
            else:
                if not processing_user_input and line:
                    response += " " + line

        # 处理文件结尾的最后一个记录
        if user_input and response:
            try:
                merged_data = merge_relations_with_entities(user_input, response)
                outfile.write(json.dumps(merged_data, ensure_ascii=False) + '\n')
                valid_data_count += 1
            except Exception as e:
                error_log.write(f"Error processing data at line {line_count}: {str(e)}\n")

    return valid_data_count

# 定义文件路径
input_path = 'RE.txt'
output_path = 'output_RE.jsonl'
error_log_path = 'log_RE.txt'

# 运行处理数据的函数
valid_data_count = process_data(input_path, output_path, error_log_path)
print(f"Total valid data count: {valid_data_count}")
# Out:
# JSONDecodeError: Unterminated string starting at: line 1 column 594 (char 593) with response: "relations": [ {"id": 1, "from_id": 6373, "start_text": "研究区混合重力数据", "to_id": 6374, "end_text": "BIMF分量", "type": "分为"}, {"id": 2, "from_id": 6374, "start_text": "BIMF分量", "to_id": 6357, "end_text": "BIMF₁", "type": "包含"}, {"id": 3, "from_id": 6357, "start_text": "BIMF₁", "to_id": 6358, "end_text": "BIMF₂", "type": "和"}, {"id": 4, "from_id": 6358, "start_text": "BIMF₂", "to_id": 6359, "end_text": "BIMF₃", "type": "和"}, {"id": 5, "from_id": 6374, "start_text": "BIMF分量", "to_id": 6359, "end_text": "BIMF₃", "type": "包含"}, {"id": 6, "from_id": 6373, "start_text": "研究区混合重力数据", "to_id": 6361, "end_text": "[Res(m,n)]", "type": "和"}, {"id": 7, "from_id": 6373, "start_text": "研究区混合重力数据", "to_id": 8651, "end_text": "3个", "type": "分为"}, {"id": 8, "from_id": 8651, "start_text": "3个", "to_id": 6360, "end_text": "频率依次降低", "type": "为"}, {"id": 9, "from_id": 6360, "start_text": "频率依次降低", "to_id": 6357, "end_text": "BIMF₁", "type": "和"}, {"id": 10, "from_id": 6360, "start_text": "频率依次降低", "to_id": 6358, "end_text": "BIMF₂", "type": "和"}, {"id": 11, "from_id": 6360, "start_text": "频率依次降低", "to_id": 6359, "end_text": "BIMF₃", "type": "和"}, {"id": 12, "from_id": 6373, "start_text": "研究区混合重力数据", "to_id": 6380, "end_text": "频率最低", "type": "和"}, {"id": 13, "from_id": 6380, "start_text": "频率最低", "to_id": 6361, "end_text": "[Res(m,n)]", "type": "为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 38 (char 37) with response: "relations":[ {"id":1,"from_id":788,"start_text":"低通滤波重力分量异常[Res(m,n)]","to_id":789,"end_text":"深部地质结构特征","type":"可能"}, {"id":2,"from_id":790,"start_text":"正重力异常","to_id":791,"end_text":"地幔和/或基岩隆起区","type":"可能"}, {"id":3,"from_id":792,"start_text":"北西向","to_id":790,"end_text":"正重力异常","type":"为"}, {"id":4,"from_id":793,"start_text":"负重力异常","to_id":794,"end_text":"地幔和/或基岩的凹陷区","type":"可能"}, {"id":5,"from_id":842,"start_text":"北西向","to_id":793,"end_text":"负重力异常","type":"为"}, {"id":6,"from_id":788,"start_text":"低通滤波重力分量异常[Res(m,n)]","to_id":790,"end_text":"正重力异常","type":"包含"}, {"id":7,"from_id":788,"start_text":"低通滤波重力分量异常[Res(m,n)]","to_id":793,"end_text":"负重力异常","type":"包含"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 686 (char 685) with response: ```json { "id": 15, "text": "世界几乎所有的岩浆深成和中深成热液矿床成矿流体的分离作用都具有类似的蚀变矿化类型和蚀变矿化空间分布模式(从深到浅，由中心到边缘):钨-锡[云英岩化] → 锡-铜[电气石-萤石化] → 铜-铅-锌-银[绿泥石化、绢云母化、黄铁矿化、硅化、碳酸化]。", "entities": [ {"id": 2097, "label": "矿床类别", "start_offset": 7, "end_offset": 19, "text": "岩浆深成和中深成热液矿床"}, {"id": 2098, "label": "条件特点", "start_offset": 19, "end_offset": 28, "text": "成矿流体的分离作用"}, {"id": 2100, "label": "矿化作用", "start_offset": 34, "end_offset": 40, "text": "蚀变矿化类型"}, {"id": 2102, "label": "矿化状态", "start_offset": 65, "end_offset": 74, "text": "钨-锡[云英岩化]"}, {"id": 2103, "label": "矿化状态", "start_offset": 77, "end_offset": 89, "text": "锡-铜[电气石-萤石化]"}, {"id": 2104, "label": "矿化状态", "start_offset": 92, "end_offset": 122, "text": "铜-铅-锌-银[绿泥石化、绢云母化、黄铁矿化、硅化、碳酸化]"}, {"id": 7776, "label": "数据参数其他", "start_offset": 41, "end_offset": 51, "text": "蚀变矿化空间分布模式"}, {"id": 7777, "label": "条件特点", "start_offset": 52, "end_offset": 56, "text": "从深到浅"}, {"id": 7778, "label": "区域与位置", "start_offset": 58, "end_offset": 60, "text": "中心"}, {"id": 7780, "label": "区域与位置", "start_offset": 61, "end_offset": 63, "text": "边缘"} ], "relations": [ {"id": 1, "from_id": 2097, "start_text": "岩浆深成和中深成热液矿床", "to_id": 2098, "end_text": "成矿流体的分离作用", "type": "具有"}, {"id": 2, "from_id": 2097, "start_text": "岩浆深成和中深成热液矿床", "to_id": 2100, "end_text": "蚀变矿化类型", "type": "具有"}, {"id": 3, "from_id": 2097, "start_text": "岩浆深成和中深成热液矿床", "to_id": 7776, "end_text": "蚀变矿化空间分布模式", "type": "具有"}, {"id": 4, "from_id": 7776, "start_text": "蚀变矿化空间分布模式", "to_id": 7777, "end_text": "从深到浅", "type": "为"}, {"id": 5, "from_id": 7776, "start_text": "蚀变矿化空间分布模式", "to_id": 7778, "end_text": "中心", "type": "由"}, {"id": 6, "from_id": 7776, "start_text": "蚀变矿化空间分布模式", "to_id": 7780, "end_text": "边缘", "type": "到"}, {"id": 7, "from_id": 2102, "start_text": "钨-锡[云英岩化]", "to_id": 2103, "end_text": "锡-铜[电气石-萤石化]", "type": "—>"}, {"id": 8, "from_id": 2103, "start_text": "锡-铜[电气石-萤石化]", "to_id": 2104, "end_text": "铜-铅-锌-银[绿泥石化、绢云母化、黄铁矿化、硅化、碳酸化]", "type": "—>"}, {"id": 9, "from_id": 2100, "start_text": "蚀变矿化类型", "to_id": 2102, "end_text": "钨-锡[云英岩化]", "type": "包含"}, {"id": 10, "from_id": 2100, "start_text": "蚀变矿化类型", "to_id": 2103, "end_text": "锡-铜[电气石-萤石化]", "type": "包含"}, {"id": 11, "from_id": 2100, "start_text": "蚀变矿化类型", "to_id": 2104, "end_text": "铜-铅-锌-银[绿泥石化、绢云母化、黄铁矿化、硅化、碳酸化]", "type": "包含"} ] } ```
# JSONDecodeError: Unterminated string starting at: line 1 column 185 (char 184) with response: "relations": [ {"id": 1, "from_id": 5559, "start_text": "表9-3", "to_id": 8993, "end_text": "原生晕的分带序列", "type": "有"}, {"id": 2, "from_id": 8993, "start_text": "原生晕的分带序列", "to_id": 8988, "end_text": "[F-B-Ba-W]", "type": "包含"}, {"id": 3, "from_id": 8988, "start_text": "[F-B-Ba-W]", "to_id": 8989, "end_text": "[Cu-Sb]", "type": "—>"}, {"id": 4, "from_id": 8989, "start_text": "[Cu-Sb]", "to_id": 8990, "end_text": "[Be-Cr]", "type": "—>"}, {"id": 5, "from_id": 8990, "start_text": "[Be-Cr]", "to_id": 8991, "end_text": "[Sn-Pb-Zn-Ni-Ag]", "type": "—>"}, {"id": 6, "from_id": 8991, "start_text": "[Sn-Pb-Zn-Ni-Ag]", "to_id": 8992, "end_text": "[Co-Mo-Bi-As]", "type": "—>"}, {"id": 7, "from_id": 8993, "start_text": "原生晕的分带序列", "to_id": 5559, "end_text": "表9-3", "type": "有"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 44 (char 43) with response: "relations": [ {"id": 1, "from_id": 5650, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5651, "end_text": "[Ba+W]D/[As+Zn+Bi]D", "type": "和"}, {"id": 2, "from_id": 5650, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 9037, "end_text": "深部矿体定量评价模型", "type": "为"}, {"id": 3, "from_id": 5651, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 9037, "end_text": "深部矿体定量评价模型", "type": "为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 1037 (char 1036) with response: "relations": [ {"id": 1, "from_id": 5652, "start_text": "矿体头部(1290m标高)", "to_id": 5653, "end_text": "1.40×10⁴", "type": "为"}, {"id": 2, "from_id": 5655, "start_text": "矿体中上部(1210m 标高)", "to_id": 5656, "end_text": "1.09×10²", "type": "为"}, {"id": 3, "from_id": 5659, "start_text": "矿体中部(1130m 标 高)", "to_id": 5660, "end_text": "5.40×102", "type": "为"}, {"id": 4, "from_id": 5661, "start_text": "矿体中下部(1030m标高)", "to_id": 5662, "end_text": "1.45×10-1", "type": "为"}, {"id": 5, "from_id": 5663, "start_text": "矿体尾部(960m标高)", "to_id": 5664, "end_text": "1.42×10-1", "type": "为"}, {"id": 6, "from_id": 5653, "start_text": "1.40×10⁴", "to_id": 5656, "end_text": "1.09×10²", "type": "—>"}, {"id": 7, "from_id": 5656, "start_text": "1.09×10²", "to_id": 5660, "end_text": "5.40×102", "type": "—>"}, {"id": 8, "from_id": 5660, "start_text": "5.40×102", "to_id": 5662, "end_text": "1.45×10-1", "type": "—>"}, {"id": 9, "from_id": 5662, "start_text": "1.45×10-1", "to_id": 5664, "end_text": "1.42×10-1", "type": "—>"}, {"id": 10, "from_id": 9038, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5652, "end_text": "矿体头部(1290m标高)", "type": "反映了"}, {"id": 11, "from_id": 9038, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5655, "end_text": "矿体中上部(1210m 标高)", "type": "反映了"}, {"id": 12, "from_id": 9038, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5659, "end_text": "矿体中部(1130m 标 高)", "type": "反映了"}, {"id": 13, "from_id": 9038, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5661, "end_text": "矿体中下部(1030m标高)", "type": "反映了"}, {"id": 14, "from_id": 9038, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5663, "end_text": "矿体尾部(960m标高)", "type": "反映了"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 44 (char 43) with response: "relations": [ {"id": 1, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 9039, "end_text": "累乘指数比值", "type": "与"}, {"id": 2, "from_id": 5670, "start_text": "矿体头部(1290m标高)", "to_id": 5671, "end_text": "4.91", "type": "为"}, {"id": 3, "from_id": 5672, "start_text": "矿体中上部(1210m标高)", "to_id": 5673, "end_text": "1.53", "type": "为"}, {"id": 4, "from_id": 5674, "start_text": "矿体中部(1130m 标高)", "to_id": 5675, "end_text": "1.93", "type": "为"}, {"id": 5, "from_id": 5676, "start_text": "矿体中下部(1030m标高)", "to_id": 5677, "end_text": "0.60", "type": "为"}, {"id": 6, "from_id": 5678, "start_text": "矿体尾部(960m标高)", "to_id": 5679, "end_text": "0.69", "type": "为"}, {"id": 7, "from_id": 5670, "start_text": "矿体头部(1290m标高)", "to_id": 5672, "end_text": "矿体中上部(1210m标高)", "type": "—>"}, {"id": 8, "from_id": 5672, "start_text": "矿体中上部(1210m标高)", "to_id": 5674, "end_text": "矿体中部(1130m 标高)", "type": "—>"}, {"id": 9, "from_id": 5674, "start_text": "矿体中部(1130m 标高)", "to_id": 5676, "end_text": "矿体中下部(1030m标高)", "type": "—>"}, {"id": 10, "from_id": 5676, "start_text": "矿体中下部(1030m标高)", "to_id": 5678, "end_text": "矿体尾部(960m标高)", "type": "—>"}, {"id": 11, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 5670, "end_text": "矿体头部(1290m标高)", "type": "反映了"}, {"id": 12, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 5672, "end_text": "矿体中上部(1210m标高)", "type": "反映了"}, {"id": 13, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 5674, "end_text": "矿体中部(1130m 标高)", "type": "反映了"}, {"id": 14, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 5676, "end_text": "矿体中下部(1030m标高)", "type": "反映了"}, {"id": 15, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 5678, "end_text": "矿体尾部(960m标高)", "type": "反映了"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 44 (char 43) with response: ```json "relations": [ {"id": 1, "from_id": 5884, "start_text": "[Zn×Ag×As]D/[Mo×Be×W]D", "to_id": 5885, "end_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "type": "和"} ] ```
# JSONDecodeError: Unterminated string starting at: line 1 column 39 (char 38) with response: "relations":[ {"id":1,"from_id":5887,"start_text":"[Zn×Ag×As]D/[Mo×Be×W]D","to_id":5886,"end_text":"矿体头部(1800m标高)","type":"表现为"}, {"id":2,"from_id":5887,"start_text":"[Zn×Ag×As]D/[Mo×Be×W]D","to_id":5888,"end_text":"1.46","type":"表现为"}, {"id":3,"from_id":5886,"start_text":"矿体头部(1800m标高)","to_id":5888,"end_text":"1.46","type":"为"}, {"id":4,"from_id":5886,"start_text":"矿体头部(1800m标高)","to_id":5889,"end_text":"矿体中上部(1740m标高)","type":"—>"}, {"id":5,"from_id":5889,"start_text":"矿体中上部(1740m标高)","to_id":5890,"end_text":"14.44","type":"为"}, {"id":6,"from_id":5889,"start_text":"矿体中上部(1740m标高)","to_id":5891,"end_text":"矿体中部 (1680m 标高)","type":"—>"}, {"id":7,"from_id":5891,"start_text":"矿体中部 (1680m 标高)","to_id":5892,"end_text":"1.44×10-3","type":"为"}, {"id":8,"from_id":5891,"start_text":"矿体中部 (1680m 标高)","to_id":5893,"end_text":"矿体中尾部(1620m标高)","type":"—>"}, {"id":9,"from_id":5893,"start_text":"矿体中尾部(1620m标高)","to_id":5894,"end_text":"9.55×10-4","type":"为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 79 (char 78) with response: "relations": [ {"id": 1, "from_id": 9205, "start_text": "累加指标", "to_id": 5895, "end_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "type": "为"}, {"id": 2, "from_id": 5896, "start_text": "矿体头部(1740m标高)", "to_id": 5897, "end_text": "1.02", "type": "为"}, {"id": 3, "from_id": 5898, "start_text": "矿体中上部(1680m标高)", "to_id": 5899, "end_text": "2.05", "type": "为"}, {"id": 4, "from_id": 5900, "start_text": "矿体中部(1620m标高)", "to_id": 5901, "end_text": "0.14", "type": "为"}, {"id": 5, "from_id": 5902, "start_text": "矿体中尾部(1560m标高)", "to_id": 5903, "end_text": "0.10", "type": "为"}, {"id": 6, "from_id": 5896, "start_text": "矿体头部(1740m标高)", "to_id": 5898, "end_text": "矿体中上部(1680m标高)", "type": "—>"}, {"id": 7, "from_id": 5898, "start_text": "矿体中上部(1680m标高)", "to_id": 5900, "end_text": "矿体中部(1620m标高)", "type": "—>"}, {"id": 8, "from_id": 5900, "start_text": "矿体中部(1620m标高)", "to_id": 5902, "end_text": "矿体中尾部(1560m标高)", "type": "—>"}, {"id": 9, "from_id": 5895, "start_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "to_id": 5896, "end_text": "矿体头部(1740m标高)", "type": "包含"}, {"id": 10, "from_id": 5895, "start_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "to_id": 5898, "end_text": "矿体中上部(1680m标高)", "type": "包含"}, {"id": 11, "from_id": 5895, "start_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "to_id": 5900, "end_text": "矿体中部(1620m标高)", "type": "包含"}, {"id": 12, "from_id": 5895, "start_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "to_id": 5902, "end_text": "矿体中尾部(1560m标高)", "type": "包含"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 44 (char 43) with response: "relations": [ {"id": 1, "from_id": 6115, "start_text": "[Mo×Bi×Zn]D/[U×B×Sb]D", "to_id": 6116, "end_text": "[Mo+Bi+Zn]D/[U+B+Sb]D", "type": "和"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 844 (char 843) with response: ```json { "relations": [ {"id": 1, "from_id": 6122, "start_text": "矿体头部(1920m标高)", "to_id": 6121, "end_text": "4.15", "type": "为"}, {"id": 2, "from_id": 6125, "start_text": "矿体中上部(1860m标高)", "to_id": 6123, "end_text": "9.64×10-4", "type": "为"}, {"id": 3, "from_id": 6126, "start_text": "矿体中下部(1820m标高)", "to_id": 6127, "end_text": "1.20×10-4", "type": "为"}, {"id": 4, "from_id": 6128, "start_text": "矿体尾部(1740m标高)", "to_id": 6129, "end_text": "5.90×10-3", "type": "为"}, {"id": 5, "from_id": 6122, "start_text": "矿体头部(1920m标高)", "to_id": 6125, "end_text": "矿体中上部(1860m标高)", "type": "—>"}, {"id": 6, "from_id": 6125, "start_text": "矿体中上部(1860m标高)", "to_id": 6126, "end_text": "矿体中下部(1820m标高)", "type": "—>"}, {"id": 7, "from_id": 6126, "start_text": "矿体中下部(1820m标高)", "to_id": 6128, "end_text": "矿体尾部(1740m标高)", "type": "—>"}, {"id": 8, "from_id": 6120, "start_text": "[Mo×Bi×Zn]D/[U×B×Sb]D", "to_id": 6122, "end_text": "矿体头部(1920m标高)", "type": "具体表现为"}, {"id": 9, "from_id": 6120, "start_text": "[Mo×Bi×Zn]D/[U×B×Sb]D", "to_id": 6125, "end_text": "矿体中上部(1860m标高)", "type": "具体表现为"}, {"id": 10, "from_id": 6120, "start_text": "[Mo×Bi×Zn]D/[U×B×Sb]D", "to_id": 6126, "end_text": "矿体中下部(1820m标高)", "type": "具体表现为"}, {"id": 11, "from_id": 6120, "start_text": "[Mo×Bi×Zn]D/[U×B×Sb]D", "to_id": 6128, "end_text": "矿体尾部(1740m标高)", "type": "具体表现为"} ] } ```
# JSONDecodeError: Unterminated string starting at: line 1 column 68 (char 67) with response: "relations":[ {"id":1,"from_id":4505,"start_text":"F₁","to_id":4504,"end_text":"[Ba-Co-Cr-Ni-V-Zn-]-[SiO₂-K₂O-Sn-Be-Bi-F]","type":"为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 77 (char 76) with response: "relations": [ {"id": 1, "from_id": 4508, "start_text": "F₂", "to_id": 4506, "end_text": "[Cu-F-Mo-Sn]-[Na₂O-Pb]", "type": "为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 68 (char 67) with response: "relations":[ {"id":1,"from_id":9145,"start_text":"F₃","to_id":4507,"end_text":"[Ag-Sb-B-Be]","type":"为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 68 (char 67) with response: "relations":[ {"id":1,"from_id":4511,"start_text":"F₄","to_id":4510,"end_text":"[Bi-Pb-W]-[Na2O]","type":"为"} ]
# Total valid data count: 994

# %%
import json
import re

def clean_json_string(json_string):
    """
    Clean JSON string to ensure it is a valid JSON array or object.
    This includes handling cases where the JSON string is not properly terminated.
    """
    json_string = json_string.strip()
    if not (json_string.startswith('{') or json_string.startswith('[')):
        json_string = '{' + json_string
    if not (json_string.endswith('}') or json_string.endswith(']')):
        json_string = json_string + '}'
    return json_string

def extract_relations(response):
    # 使用正则表达式提取 "relations" 部分，处理不完整的数组
    match = re.search(r'"relations":\s*(\[[^\]]*\])', response, re.DOTALL)
    if match:
        return match.group(1)
    return "[]"

def merge_relations_with_entities(user_input, response):
    user_data = json.loads(user_input)

    try:
        relations_str = extract_relations(response)
        relations_str = clean_json_string(relations_str)
        relations_data = json.loads(relations_str)
        user_data['relations'] = relations_data
    except json.JSONDecodeError as e:
        print(f"JSONDecodeError: {str(e)} with response: {response}")
        user_data['relations'] = []
    except Exception as e:
        print(f"Error merging data: {str(e)}")
        user_data['relations'] = []

    return user_data

def process_data(input_path, output_path, error_log_path):
    line_count = 0
    valid_data_count = 0

    with open(input_path, 'r', encoding='utf-8') as infile, open(output_path, 'w', encoding='utf-8') as outfile, open(error_log_path, 'w', encoding='utf-8') as error_log:
        lines = infile.readlines()
        user_input = ""
        response_lines = []
        processing_user_input = False

        for line in lines:
            line_count += 1
            line = line.strip()

            if line.startswith("User Input:"):
                if user_input and response_lines:
                    response = ' '.join(response_lines)
                    try:
                        merged_data = merge_relations_with_entities(user_input, response)
                        outfile.write(json.dumps(merged_data, ensure_ascii=False) + '\n')
                        valid_data_count += 1
                    except Exception as e:
                        error_log.write(f"Error processing data at line {line_count}: {str(e)}\n")
                user_input = line.replace("User Input: ", "")
                response_lines = []
                processing_user_input = True
                error_log.write(f"Read User Input: {user_input}\n")  # Debug log
            elif line.startswith("Response:"):
                processing_user_input = False
                response = line.replace("Response: ", "")
                response_lines.append(response)
                error_log.write(f"Read Response: {response}\n")  # Debug log
            else:
                if not processing_user_input and line:
                    response_lines.append(line)

        # 处理文件结尾的最后一个记录
        if user_input and response_lines:
            response = ' '.join(response_lines)
            try:
                merged_data = merge_relations_with_entities(user_input, response)
                outfile.write(json.dumps(merged_data, ensure_ascii=False) + '\n')
                valid_data_count += 1
            except Exception as e:
                error_log.write(f"Error processing data at line {line_count}: {str(e)}\n")

    return valid_data_count

# 定义文件路径
input_path = 'RE.jsonal'
output_path = 'output_RE.jsonl'
error_log_path = 'log_RE.txt'

# 运行处理数据的函数
valid_data_count = process_data(input_path, output_path, error_log_path)
print(f"Total valid data count: {valid_data_count}")
# Out:
# JSONDecodeError: Unterminated string starting at: line 1 column 594 (char 593) with response: "relations": [ {"id": 1, "from_id": 6373, "start_text": "研究区混合重力数据", "to_id": 6374, "end_text": "BIMF分量", "type": "分为"}, {"id": 2, "from_id": 6374, "start_text": "BIMF分量", "to_id": 6357, "end_text": "BIMF₁", "type": "包含"}, {"id": 3, "from_id": 6357, "start_text": "BIMF₁", "to_id": 6358, "end_text": "BIMF₂", "type": "和"}, {"id": 4, "from_id": 6358, "start_text": "BIMF₂", "to_id": 6359, "end_text": "BIMF₃", "type": "和"}, {"id": 5, "from_id": 6374, "start_text": "BIMF分量", "to_id": 6359, "end_text": "BIMF₃", "type": "包含"}, {"id": 6, "from_id": 6373, "start_text": "研究区混合重力数据", "to_id": 6361, "end_text": "[Res(m,n)]", "type": "和"}, {"id": 7, "from_id": 6373, "start_text": "研究区混合重力数据", "to_id": 8651, "end_text": "3个", "type": "分为"}, {"id": 8, "from_id": 8651, "start_text": "3个", "to_id": 6360, "end_text": "频率依次降低", "type": "为"}, {"id": 9, "from_id": 6360, "start_text": "频率依次降低", "to_id": 6357, "end_text": "BIMF₁", "type": "和"}, {"id": 10, "from_id": 6360, "start_text": "频率依次降低", "to_id": 6358, "end_text": "BIMF₂", "type": "和"}, {"id": 11, "from_id": 6360, "start_text": "频率依次降低", "to_id": 6359, "end_text": "BIMF₃", "type": "和"}, {"id": 12, "from_id": 6373, "start_text": "研究区混合重力数据", "to_id": 6380, "end_text": "频率最低", "type": "和"}, {"id": 13, "from_id": 6380, "start_text": "频率最低", "to_id": 6361, "end_text": "[Res(m,n)]", "type": "为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 38 (char 37) with response: "relations":[ {"id":1,"from_id":788,"start_text":"低通滤波重力分量异常[Res(m,n)]","to_id":789,"end_text":"深部地质结构特征","type":"可能"}, {"id":2,"from_id":790,"start_text":"正重力异常","to_id":791,"end_text":"地幔和/或基岩隆起区","type":"可能"}, {"id":3,"from_id":792,"start_text":"北西向","to_id":790,"end_text":"正重力异常","type":"为"}, {"id":4,"from_id":793,"start_text":"负重力异常","to_id":794,"end_text":"地幔和/或基岩的凹陷区","type":"可能"}, {"id":5,"from_id":842,"start_text":"北西向","to_id":793,"end_text":"负重力异常","type":"为"}, {"id":6,"from_id":788,"start_text":"低通滤波重力分量异常[Res(m,n)]","to_id":790,"end_text":"正重力异常","type":"包含"}, {"id":7,"from_id":788,"start_text":"低通滤波重力分量异常[Res(m,n)]","to_id":793,"end_text":"负重力异常","type":"包含"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 686 (char 685) with response: Response: "relations": [ {"id": 1, "from_id": 2097, "start_text": "岩浆深成和中深成热液矿床", "to_id": 2098, "end_text": "成矿流体的分离作用", "type": "具有"}, {"id": 2, "from_id": 2097, "start_text": "岩浆深成和中深成热液矿床", "to_id": 2100, "end_text": "蚀变矿化类型", "type": "具有"}, {"id": 3, "from_id": 2097, "start_text": "岩浆深成和中深成热液矿床", "to_id": 7776, "end_text": "蚀变矿化空间分布模式", "type": "具有"}, {"id": 4, "from_id": 7776, "start_text": "蚀变矿化空间分布模式", "to_id": 7777, "end_text": "从深到浅", "type": "为"}, {"id": 5, "from_id": 7776, "start_text": "蚀变矿化空间分布模式", "to_id": 7778, "end_text": "中心", "type": "由"}, {"id": 6, "from_id": 7776, "start_text": "蚀变矿化空间分布模式", "to_id": 7780, "end_text": "边缘", "type": "到"}, {"id": 7, "from_id": 2102, "start_text": "钨-锡[云英岩化]", "to_id": 2103, "end_text": "锡-铜[电气石-萤石化]", "type": "—>"}, {"id": 8, "from_id": 2103, "start_text": "锡-铜[电气石-萤石化]", "to_id": 2104, "end_text": "铜-铅-锌-银[绿泥石化、绢云母化、黄铁矿化、硅化、碳酸化]", "type": "—>"}, {"id": 9, "from_id": 2100, "start_text": "蚀变矿化类型", "to_id": 2102, "end_text": "钨-锡[云英岩化]", "type": "包含"}, {"id": 10, "from_id": 2100, "start_text": "蚀变矿化类型", "to_id": 2103, "end_text": "锡-铜[电气石-萤石化]", "type": "包含"}, {"id": 11, "from_id": 2100, "start_text": "蚀变矿化类型", "to_id": 2104, "end_text": "铜-铅-锌-银[绿泥石化、绢云母化、黄铁矿化、硅化、碳酸化]", "type": "包含"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 185 (char 184) with response: "relations": [ {"id": 1, "from_id": 5559, "start_text": "表9-3", "to_id": 8993, "end_text": "原生晕的分带序列", "type": "有"}, {"id": 2, "from_id": 8993, "start_text": "原生晕的分带序列", "to_id": 8988, "end_text": "[F-B-Ba-W]", "type": "包含"}, {"id": 3, "from_id": 8988, "start_text": "[F-B-Ba-W]", "to_id": 8989, "end_text": "[Cu-Sb]", "type": "—>"}, {"id": 4, "from_id": 8989, "start_text": "[Cu-Sb]", "to_id": 8990, "end_text": "[Be-Cr]", "type": "—>"}, {"id": 5, "from_id": 8990, "start_text": "[Be-Cr]", "to_id": 8991, "end_text": "[Sn-Pb-Zn-Ni-Ag]", "type": "—>"}, {"id": 6, "from_id": 8991, "start_text": "[Sn-Pb-Zn-Ni-Ag]", "to_id": 8992, "end_text": "[Co-Mo-Bi-As]", "type": "—>"}, {"id": 7, "from_id": 8993, "start_text": "原生晕的分带序列", "to_id": 5559, "end_text": "表9-3", "type": "有"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 44 (char 43) with response: "relations": [ {"id": 1, "from_id": 5650, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5651, "end_text": "[Ba+W]D/[As+Zn+Bi]D", "type": "和"}, {"id": 2, "from_id": 5650, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 9037, "end_text": "深部矿体定量评价模型", "type": "为"}, {"id": 3, "from_id": 5651, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 9037, "end_text": "深部矿体定量评价模型", "type": "为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 1037 (char 1036) with response: "relations": [ {"id": 1, "from_id": 5652, "start_text": "矿体头部(1290m标高)", "to_id": 5653, "end_text": "1.40×10⁴", "type": "为"}, {"id": 2, "from_id": 5655, "start_text": "矿体中上部(1210m 标高)", "to_id": 5656, "end_text": "1.09×10²", "type": "为"}, {"id": 3, "from_id": 5659, "start_text": "矿体中部(1130m 标 高)", "to_id": 5660, "end_text": "5.40×102", "type": "为"}, {"id": 4, "from_id": 5661, "start_text": "矿体中下部(1030m标高)", "to_id": 5662, "end_text": "1.45×10-1", "type": "为"}, {"id": 5, "from_id": 5663, "start_text": "矿体尾部(960m标高)", "to_id": 5664, "end_text": "1.42×10-1", "type": "为"}, {"id": 6, "from_id": 5653, "start_text": "1.40×10⁴", "to_id": 5656, "end_text": "1.09×10²", "type": "—>"}, {"id": 7, "from_id": 5656, "start_text": "1.09×10²", "to_id": 5660, "end_text": "5.40×102", "type": "—>"}, {"id": 8, "from_id": 5660, "start_text": "5.40×102", "to_id": 5662, "end_text": "1.45×10-1", "type": "—>"}, {"id": 9, "from_id": 5662, "start_text": "1.45×10-1", "to_id": 5664, "end_text": "1.42×10-1", "type": "—>"}, {"id": 10, "from_id": 9038, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5652, "end_text": "矿体头部(1290m标高)", "type": "反映了"}, {"id": 11, "from_id": 9038, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5655, "end_text": "矿体中上部(1210m 标高)", "type": "反映了"}, {"id": 12, "from_id": 9038, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5659, "end_text": "矿体中部(1130m 标 高)", "type": "反映了"}, {"id": 13, "from_id": 9038, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5661, "end_text": "矿体中下部(1030m标高)", "type": "反映了"}, {"id": 14, "from_id": 9038, "start_text": "[Ba×W]D/[As×Zn×Bi]D", "to_id": 5663, "end_text": "矿体尾部(960m标高)", "type": "反映了"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 44 (char 43) with response: "relations": [ {"id": 1, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 9039, "end_text": "累乘指数比值", "type": "与"}, {"id": 2, "from_id": 5670, "start_text": "矿体头部(1290m标高)", "to_id": 5671, "end_text": "4.91", "type": "为"}, {"id": 3, "from_id": 5672, "start_text": "矿体中上部(1210m标高)", "to_id": 5673, "end_text": "1.53", "type": "为"}, {"id": 4, "from_id": 5674, "start_text": "矿体中部(1130m 标高)", "to_id": 5675, "end_text": "1.93", "type": "为"}, {"id": 5, "from_id": 5676, "start_text": "矿体中下部(1030m标高)", "to_id": 5677, "end_text": "0.60", "type": "为"}, {"id": 6, "from_id": 5678, "start_text": "矿体尾部(960m标高)", "to_id": 5679, "end_text": "0.69", "type": "为"}, {"id": 7, "from_id": 5670, "start_text": "矿体头部(1290m标高)", "to_id": 5672, "end_text": "矿体中上部(1210m标高)", "type": "—>"}, {"id": 8, "from_id": 5672, "start_text": "矿体中上部(1210m标高)", "to_id": 5674, "end_text": "矿体中部(1130m 标高)", "type": "—>"}, {"id": 9, "from_id": 5674, "start_text": "矿体中部(1130m 标高)", "to_id": 5676, "end_text": "矿体中下部(1030m标高)", "type": "—>"}, {"id": 10, "from_id": 5676, "start_text": "矿体中下部(1030m标高)", "to_id": 5678, "end_text": "矿体尾部(960m标高)", "type": "—>"}, {"id": 11, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 5670, "end_text": "矿体头部(1290m标高)", "type": "反映了"}, {"id": 12, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 5672, "end_text": "矿体中上部(1210m标高)", "type": "反映了"}, {"id": 13, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 5674, "end_text": "矿体中部(1130m 标高)", "type": "反映了"}, {"id": 14, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 5676, "end_text": "矿体中下部(1030m标高)", "type": "反映了"}, {"id": 15, "from_id": 5669, "start_text": "[Ba+W]D/[As+Zn+Bi]D", "to_id": 5678, "end_text": "矿体尾部(960m标高)", "type": "反映了"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 44 (char 43) with response: Response: "relations": [ {"id": 1, "from_id": 5884, "start_text": "[Zn×Ag×As]D/[Mo×Be×W]D", "to_id": 5885, "end_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "type": "和"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 39 (char 38) with response: "relations":[ {"id":1,"from_id":5887,"start_text":"[Zn×Ag×As]D/[Mo×Be×W]D","to_id":5886,"end_text":"矿体头部(1800m标高)","type":"表现为"}, {"id":2,"from_id":5887,"start_text":"[Zn×Ag×As]D/[Mo×Be×W]D","to_id":5888,"end_text":"1.46","type":"表现为"}, {"id":3,"from_id":5886,"start_text":"矿体头部(1800m标高)","to_id":5888,"end_text":"1.46","type":"为"}, {"id":4,"from_id":5886,"start_text":"矿体头部(1800m标高)","to_id":5889,"end_text":"矿体中上部(1740m标高)","type":"—>"}, {"id":5,"from_id":5889,"start_text":"矿体中上部(1740m标高)","to_id":5890,"end_text":"14.44","type":"为"}, {"id":6,"from_id":5889,"start_text":"矿体中上部(1740m标高)","to_id":5891,"end_text":"矿体中部 (1680m 标高)","type":"—>"}, {"id":7,"from_id":5891,"start_text":"矿体中部 (1680m 标高)","to_id":5892,"end_text":"1.44×10-3","type":"为"}, {"id":8,"from_id":5891,"start_text":"矿体中部 (1680m 标高)","to_id":5893,"end_text":"矿体中尾部(1620m标高)","type":"—>"}, {"id":9,"from_id":5893,"start_text":"矿体中尾部(1620m标高)","to_id":5894,"end_text":"9.55×10-4","type":"为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 79 (char 78) with response: "relations": [ {"id": 1, "from_id": 9205, "start_text": "累加指标", "to_id": 5895, "end_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "type": "为"}, {"id": 2, "from_id": 5896, "start_text": "矿体头部(1740m标高)", "to_id": 5897, "end_text": "1.02", "type": "为"}, {"id": 3, "from_id": 5898, "start_text": "矿体中上部(1680m标高)", "to_id": 5899, "end_text": "2.05", "type": "为"}, {"id": 4, "from_id": 5900, "start_text": "矿体中部(1620m标高)", "to_id": 5901, "end_text": "0.14", "type": "为"}, {"id": 5, "from_id": 5902, "start_text": "矿体中尾部(1560m标高)", "to_id": 5903, "end_text": "0.10", "type": "为"}, {"id": 6, "from_id": 5896, "start_text": "矿体头部(1740m标高)", "to_id": 5898, "end_text": "矿体中上部(1680m标高)", "type": "—>"}, {"id": 7, "from_id": 5898, "start_text": "矿体中上部(1680m标高)", "to_id": 5900, "end_text": "矿体中部(1620m标高)", "type": "—>"}, {"id": 8, "from_id": 5900, "start_text": "矿体中部(1620m标高)", "to_id": 5902, "end_text": "矿体中尾部(1560m标高)", "type": "—>"}, {"id": 9, "from_id": 5895, "start_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "to_id": 5896, "end_text": "矿体头部(1740m标高)", "type": "包含"}, {"id": 10, "from_id": 5895, "start_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "to_id": 5898, "end_text": "矿体中上部(1680m标高)", "type": "包含"}, {"id": 11, "from_id": 5895, "start_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "to_id": 5900, "end_text": "矿体中部(1620m标高)", "type": "包含"}, {"id": 12, "from_id": 5895, "start_text": "[Zn+Ag+As]D/[Mo+Be+W]D", "to_id": 5902, "end_text": "矿体中尾部(1560m标高)", "type": "包含"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 44 (char 43) with response: "relations": [ {"id": 1, "from_id": 6115, "start_text": "[Mo×Bi×Zn]D/[U×B×Sb]D", "to_id": 6116, "end_text": "[Mo+Bi+Zn]D/[U+B+Sb]D", "type": "和"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 844 (char 843) with response: Response: "relations": [ {"id": 1, "from_id": 6122, "start_text": "矿体头部(1920m标高)", "to_id": 6121, "end_text": "4.15", "type": "为"}, {"id": 2, "from_id": 6125, "start_text": "矿体中上部(1860m标高)", "to_id": 6123, "end_text": "9.64×10-4", "type": "为"}, {"id": 3, "from_id": 6126, "start_text": "矿体中下部(1820m标高)", "to_id": 6127, "end_text": "1.20×10-4", "type": "为"}, {"id": 4, "from_id": 6128, "start_text": "矿体尾部(1740m标高)", "to_id": 6129, "end_text": "5.90×10-3", "type": "为"}, {"id": 5, "from_id": 6122, "start_text": "矿体头部(1920m标高)", "to_id": 6125, "end_text": "矿体中上部(1860m标高)", "type": "—>"}, {"id": 6, "from_id": 6125, "start_text": "矿体中上部(1860m标高)", "to_id": 6126, "end_text": "矿体中下部(1820m标高)", "type": "—>"}, {"id": 7, "from_id": 6126, "start_text": "矿体中下部(1820m标高)", "to_id": 6128, "end_text": "矿体尾部(1740m标高)", "type": "—>"}, {"id": 8, "from_id": 6120, "start_text": "[Mo×Bi×Zn]D/[U×B×Sb]D", "to_id": 6122, "end_text": "矿体头部(1920m标高)", "type": "具体表现为"}, {"id": 9, "from_id": 6120, "start_text": "[Mo×Bi×Zn]D/[U×B×Sb]D", "to_id": 6125, "end_text": "矿体中上部(1860m标高)", "type": "具体表现为"}, {"id": 10, "from_id": 6120, "start_text": "[Mo×Bi×Zn]D/[U×B×Sb]D", "to_id": 6126, "end_text": "矿体中下部(1820m标高)", "type": "具体表现为"}, {"id": 11, "from_id": 6120, "start_text": "[Mo×Bi×Zn]D/[U×B×Sb]D", "to_id": 6128, "end_text": "矿体尾部(1740m标高)", "type": "具体表现为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 68 (char 67) with response: "relations":[ {"id":1,"from_id":4505,"start_text":"F₁","to_id":4504,"end_text":"[Ba-Co-Cr-Ni-V-Zn-]-[SiO₂-K₂O-Sn-Be-Bi-F]","type":"为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 77 (char 76) with response: "relations": [ {"id": 1, "from_id": 4508, "start_text": "F₂", "to_id": 4506, "end_text": "[Cu-F-Mo-Sn]-[Na₂O-Pb]", "type": "为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 68 (char 67) with response: "relations":[ {"id":1,"from_id":9145,"start_text":"F₃","to_id":4507,"end_text":"[Ag-Sb-B-Be]","type":"为"} ]
# JSONDecodeError: Unterminated string starting at: line 1 column 68 (char 67) with response: "relations":[ {"id":1,"from_id":4511,"start_text":"F₄","to_id":4510,"end_text":"[Bi-Pb-W]-[Na2O]","type":"为"} ]
# Total valid data count: 994

# %%
import json
import re

def clean_json_string(json_string):
    """
    Clean JSON string to ensure it is a valid JSON array.
    """
    json_string = json_string.strip()
    if not json_string.startswith('['):
        json_string = '[' + json_string
    if not json_string.endswith(']'):
        json_string = json_string + ']'
    return json_string

def extract_relations(response):
    """
    Extract the "relations" portion from the response.
    """
    match = re.search(r'"relations":\s*(\[.*)', response, re.DOTALL)
    if match:
        relations_str = match.group(1)
        # Try to find the matching closing bracket for the JSON array
        open_brackets = 0
        for i, char in enumerate(relations_str):
            if char == '[':
                open_brackets += 1
            elif char == ']':
                open_brackets -= 1
                if open_brackets == 0:
                    return relations_str[:i+1]
    return "[]"

def merge_relations_with_entities(user_input, response):
    """
    Merge the relations data with the user input JSON.
    """
    user_data = json.loads(user_input)

    try:
        relations_str = extract_relations(response)
        relations_str = clean_json_string(relations_str)
        relations_data = json.loads(relations_str)
        user_data['relations'] = relations_data
    except json.JSONDecodeError as e:
        print(f"JSONDecodeError: {str(e)} with response: {response}")
        user_data['relations'] = []
    except Exception as e:
        print(f"Error merging data: {str(e)}")
        user_data['relations'] = []

    return user_data

def process_data(input_path, output_path, error_log_path):
    """
    Process the input file, extract the relations data, and merge with the user input data.
    """
    line_count = 0
    valid_data_count = 0

    with open(input_path, 'r', encoding='utf-8') as infile, open(output_path, 'w', encoding='utf-8') as outfile, open(error_log_path, 'w', encoding='utf-8') as error_log:
        lines = infile.readlines()
        user_input = ""
        response_lines = []
        processing_user_input = False

        for line in lines:
            line_count += 1
            line = line.strip()

            if line.startswith("User Input:"):
                if user_input and response_lines:
                    response = ' '.join(response_lines)
                    try:
                        merged_data = merge_relations_with_entities(user_input, response)
                        outfile.write(json.dumps(merged_data, ensure_ascii=False) + '\n')
                        valid_data_count += 1
                    except Exception as e:
                        error_log.write(f"Error processing data at line {line_count}: {str(e)}\n")
                user_input = line.replace("User Input: ", "")
                response_lines = []
                processing_user_input = True
                error_log.write(f"Read User Input: {user_input}\n")  # Debug log
            elif line.startswith("Response:"):
                processing_user_input = False
                response = line.replace("Response: ", "")
                response_lines.append(response)
                error_log.write(f"Read Response: {response}\n")  # Debug log
            else:
                if not processing_user_input and line:
                    response_lines.append(line)

        # 处理文件结尾的最后一个记录
        if user_input and response_lines:
            response = ' '.join(response_lines)
            try:
                merged_data = merge_relations_with_entities(user_input, response)
                outfile.write(json.dumps(merged_data, ensure_ascii=False) + '\n')
                valid_data_count += 1
            except Exception as e:
                error_log.write(f"Error processing data at line {line_count}: {str(e)}\n")

    return valid_data_count

# 定义文件路径
input_path = 'RE.jsonal'
output_path = 'output_RE.jsonl'
error_log_path = 'log_RE.txt'

# 运行处理数据的函数
valid_data_count = process_data(input_path, output_path, error_log_path)
valid_data_count
# Out:
# 994
